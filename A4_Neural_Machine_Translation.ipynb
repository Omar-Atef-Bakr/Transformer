# %% [markdown]
# # Notebook for Programming in Problem 4
# Welcome to the programming portion of the assignment! Each assignment throughout the semester will have a written portion and a programming portion. We will be using [Google Colab](https://colab.research.google.com/notebooks/intro.ipynb#recent=true), so if you have never used it before, take a quick look through this introduction: [Working with Google Colab](https://docs.google.com/document/d/1LlnXoOblXwW3YX-0yG_5seTXJsb3kRdMMRYqs8Qqum4/edit?usp=sharing).

# %% [markdown]
# ## Learning Objectives
# In this problem, we will use [PyTorch](https://pytorch.org/) to implement a sequence-to-sequence (seq2seq) transformer model to build a nerual machine translation (NMT) system, which translates from French to English.

# %% [markdown]
# ## Writing Code
# Look for the keyword "TODO" and fill in your code in the empty space.
# You can edit code in the other parts of the notebook too, which can be useful for debugging, but be careful to avoid breaking the provided code.

# %% [markdown]
# ## Installing Packages
#
# Install PyTorch using pip. See [https://pytorch.org/](https://pytorch.org/) if you want to install it on your computer.
# In addition, we will also be needing [huggingface](https://huggingface.co/)'s `transformers` and `datasets` libraries, and [nltk](https://www.nltk.org/) to compute the BLEU score.

# %%
# Pytorch is typically already installed in Google Colab (uncomment to install):
# !pip install torch==1.8.0
# or for GPU support:
# !pip install torch==1.8.0+cu111 -f https://download.pytorch.org/whl/torch_stable.html
# !pip install transformers==4.27.0
# !pip install datasets==2.10.0
# NLTK is typically also already installed in Google Colab (uncomment to install):
# !pip install nltk==3.8.1

# %% [markdown]
# ## Download NMT data

# %% [markdown]
# We first download the data for NMT, which contains pairs of parallel sentences.

# %%
# !wget https://princeton-nlp.github.io/cos484/assignments/a4/resources.zip
# !unzip -o resources.zip

# %% [markdown]
# ## Data preprocessing
# In this section we will write code to load and tokenize the data for NMT.
#
#
# The parallel data is provided as huggingface datasets, one for each split of `train`, `validation` and `test`. We load it via the `load_from_disk` method and inspect its features. If you'd like to know more about these dataset objects, have a look at [this tutorial](https://huggingface.co/docs/datasets/access).

# %%
from datasets import load_from_disk
raw_text_datasets = load_from_disk("resources/parallel_en_fr_corpus")
print("Summary of splits:", raw_text_datasets)
print("First training example:", raw_text_datasets["train"][0])
# Out:
# Summary of splits: DatasetDict({
#     train: Dataset({
#         features: ['text_en', 'text_fr'],
#         num_rows: 8701
#     })
#     validation: Dataset({
#         features: ['text_en', 'text_fr'],
#         num_rows: 485
#     })
#     test: Dataset({
#         features: ['text_en', 'text_fr'],
#         num_rows: 486
#     })
# })
# First training example: {'text_en': 'i m tough .', 'text_fr': 'je suis dure .'}

# %% [markdown]
# You are also provided with two pre-trained tokenizers for the source and target languages respectively, which we can load with the hugginface transfomers library. [This tutorial](https://huggingface.co/docs/transformers/preprocessing#natural-language-processing) provides an introduction to using pre-trained tokenizers and the powerful `AutoTokenizer` class. The tokenizers are based on byte-pair encodings which break words into smaller units. This is aimed at reducing the sparsity of words, as subwords can be shared between different rare words. If you are interested in learning more, see the paper [Neural Machine Translation of Rare Words with Subword Units](https://www.aclweb.org/anthology/P16-1162.pdf).

# %%
from transformers import AutoTokenizer 
source_tokenizer = AutoTokenizer.from_pretrained("resources/tokenizer_fr")
target_tokenizer = AutoTokenizer.from_pretrained("resources/tokenizer_en")

print("Vocab size of source language:", source_tokenizer.vocab_size)
print("Vocab size of target language:", target_tokenizer.vocab_size)

# As a demonstration, we will the following English sentence to tokens.
example_sentence = "we have an example"
tokenizer_output = target_tokenizer(example_sentence)
print("\n*** Example ***")
print("Example sentence:", example_sentence)
print("Tokenizer output:", tokenizer_output)

# We convert every token id to its associated string, but find the special character ▁ which indicates the beginning of a word.
# Note that very common words are represented by a single token, while others are split into subunits due to the small vocab size.
# Also note that †he tokenizer already adds special tokens to the beginning and end of the sentence.
decoded_sequence = [target_tokenizer.decode(token) for token in tokenizer_output["input_ids"]]
print("Tokens:", decoded_sequence)

# By replacing the special character ▁ with whitespace, we can reconstruct a legibile sentence,
# which differs from the original example by special tokens, includings <unk> tokens, and minor whitespace differences. 
reconstructed = "".join(decoded_sequence).replace("▁", " ")
print("Reconstructed sentence", reconstructed)
# Out:
# Vocab size of source language: 3200
# Vocab size of target language: 3200
#
# *** Example ***
# Example sentence: we have an example
# Tokenizer output: {'input_ids': [1, 64, 324, 103, 266, 1490, 92, 2], 'token_type_ids': [0, 0, 0, 0, 0, 0, 0, 0], 'attention_mask': [1, 1, 1, 1, 1, 1, 1, 1]}
# Tokens: ['<s>', '▁we', '▁have', '▁an', '▁ex', 'amp', 'le', '</s>']
# Reconstructed sentence <s> we have an example</s>

# %% [markdown]
# We now want to convert the entire dataset to token ids.
# Specifically, we want to use the tokenizers to create a dataset with
# features "encoder_input_ids" and "decoder_input_ids", which both have type `List[int]`
# and which will later be the inputs to our encoder-decoder model. We will implement this using the powerful `map` function. You can find its API reference [here](https://huggingface.co/docs/datasets/v2.10.0/en/package_reference/main_classes#datasets.Dataset.map).

# %%
from typing import Dict, List

def map_example(example: Dict[str, str]) -> Dict[str, List[int]]: 
    # TODO: Tokenize the source and target text for an entry in the parallel dataset
    # and return a dictionary with the keys "encoder_input_ids" and "decoder_input_ids".
    # You can use `source_tokenizer` and `target_tokenizer`
    dict_output = {}
    dict_output["encoder_input_ids"] = source_tokenizer.encode(example["text_fr"], return_tensors="pt").squeeze().tolist()
    dict_output["decoder_input_ids"] = target_tokenizer.encode(example["text_en"], return_tensors="pt").squeeze().tolist()
    return dict_output
    
# When mapped is applied to the DatasetDict object, it will apply `map` separately to each split.
tokenized_datasets = raw_text_datasets.map(map_example, batched=False)

# The `remove_columns` removes the existing text features from the new dataset, as they are no longer needed.
tokenized_datasets = tokenized_datasets.remove_columns(raw_text_datasets.column_names["train"])

# Sanity checks on the new dataset 
assert set(tokenized_datasets.column_names["train"]) == {"decoder_input_ids", "encoder_input_ids"}
assert len(tokenized_datasets["train"]) == len(raw_text_datasets["train"])
# Out:
# Loading cached processed dataset at C:\Users\user\Repos\Transformer\resources\parallel_en_fr_corpus\train\cache-a08560e08d381f59.arrow
# Loading cached processed dataset at C:\Users\user\Repos\Transformer\resources\parallel_en_fr_corpus\validation\cache-9a1baa07bb86ad4d.arrow
# Loading cached processed dataset at C:\Users\user\Repos\Transformer\resources\parallel_en_fr_corpus\test\cache-ee38fb40e2cb12fa.arrow

# %% [markdown]
# ## Transformer model for NMT

# %% [markdown]
# We will now implement a encoder-decoder transformer model.
# We already provide code for the Feedforward Layers and Transformer Blocks, but you will have to implement the MultiHeadAttention and Embedding layer from scratch, as well as registering all the layers in the final EncoderDecoderModel. Pay attention to doc-strings and typing information to understand the context and purpose of each missing code block!

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

import math
from typing import Optional, Dict, List, Tuple

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self,
                 hidden_size: int,
                 num_attention_heads: int,
                 is_causal_attention: bool = False,
                 is_cross_attention: bool = False):
        """Defines a flexible multi-head attention layer. 
        
        This layer should define parameters for the query, key and value projections, as well as the output projection,
        and implement the following steps:
        (1) Project the input vectors using query projection and key projection matrices.
        (2) Compute the head-wise attention scores scaled by 1/sqrt(head_dim)
        (3) Perform appropriate masking to the attention scores using key_padding_mask and optionally causal attention.
        (4) Normalize the head-wise attention scores using softmax.
        (5) Compute the value projections and then aggregate using the normalized attention scores.
        (6) Use the output projection to obtain the final output vectors.
        When is_cross_attention is True, the key and value projections are computed from the encoder outputs.
        Note that we do not use attention weight dropout in this implementation.
        
        Args:
            hidden_size: The dimensionality of the input vectors.
            num_attention_heads: The number of attention heads.
            is_causal_attention: Whether to use causal masking,
                    where tokens cannot attend to the future tokens on their right.
            is_cross_attention: Whether to use cross attention,
                    where we use different inputs for the key/value vs. query vectors.
        """
        super().__init__()
        assert hidden_size % num_attention_heads == 0, "The hidden size must be divisible by the number of attention heads."
        self.head_dim = hidden_size // num_attention_heads  # embedding dimension of query and key vectors per head
        
        # TODO Initialize the module and its parameters here.
        # This module should be able to handle both full self-attention, causal masked self-attention and cross-attention.
        # IMPORTANT: You are not allowed to use `nn.MultiheadAttention` or `nn.functional.scaled_dot_product_attention`!
        
        # The respective weights of the key query and value matrices
        self.wq = nn.Linear(hidden_size, hidden_size)
        self.wk = nn.Linear(hidden_size, hidden_size)
        self.wv = nn.Linear(hidden_size, hidden_size)
        
        self.is_causal_attention = is_causal_attention
        self.is_cross_attention = is_cross_attention
        self.num_attention_heads = num_attention_heads
        
        self.normalization_value = math.sqrt(self.head_dim)
        
        
    def causal_attention_mask(self,
                              sequence_length: int, 
                              device: Optional[torch.device] = None) -> torch.FloatTensor:
        """Return a Float tensor that can be added to the (un-normalized) attention scores for causal masking.
        
        Args:
            sequence_length: width and height of the attention mask tensor.
            device: which torch device the resulting tensor should be on (important if you use GPU).

        Returns:
            A Float tensor of shape (1, 1, sequence_length, sequence_length) on device `device`,
            where the entries above the diagonal contain large negative values, 
            which means that a query at position i can't attend to a key at position j>i.
        """

        # TODO Implement the forward function.
        # IMPORTANT: For full credit, you should not use python loops.
        #
        # Hint 1: You can pick an arbitrary large value (e.g., -10^{6}), but note that
        #         using `float("-inf")` might lead to numerical issues and 'nan' values during training.
        #
        # Hint 2: Useful pytorch functions for this are `torch.arange` or `torch.triu`.
        #
        # Hint 3: You can move the tensor you create to a device by calling `tensor.to(device)`
        #
        # You should use this function in `forward` and use the returned tensor to implement causal masking
        # by adding it to the un-normalized attention scores of shape (batch_size, num_heads, sequence_length, sequence_length),
        # as torch will handle broadcasting and expand the first two dimensions to batch size and num_heads.
        #
        # You will the masking tensor to be on the same device as the attention scores's device,
        # which you can via the attribute `tensor.device`.
        
        mask = torch.ones((sequence_length, sequence_length))
        mask = mask.triu(1) * -1e9
        # mask = mask.masked_fill_(mask == 0, -1e9)
        
        if device is not None:
            mask = mask.to(device)
            
        return mask.unsqueeze(0).unsqueeze(0)


    def forward(self,
                hidden_states: torch.FloatTensor,
                key_padding_mask: torch.BoolTensor,
                encoder_outputs: Optional[torch.FloatTensor] = None) -> Tuple[torch.FloatTensor, torch.FloatTensor]:
        """Computes scaled dot-product attention and returns the output of the attention layer.
        
        Args:
            hidden_states: Tensor of shape (batch_size, sequence_length, hidden_size) - the input vectors to the layer.
            key_padding_mask: Tensor of shape (batch_size, sequence_length) indicating which tokens are padding tokens.
                    A `True` entry means that this token should be ignored for the purpose of attention.
                    In the case of cross-attention, the tensor has shape (batch_size, encoder_sequence_length).
            encoder_outputs: Optional tensor of shape (batch_size, encoder_sequence_length, hidden_size).
                    The output vectors of the encoder and only passed if the layer performs cross-attention.
                    
        Returns:
            A (layer_output, attention_weights) where layer_output is a tensor of shape (batch_size, sequence_length, hidden_size)
            and attention_weights are the normalized attention scores in the form of
            a tensor of shape (batch_size, num_attention_heads, number_of_query_tokens, number_of_key_tokens).
        """
        
        # TODO Implement the forward function.
        # IMPORTANT: For full credit, you should not use python loops. Furthermore, 
        #            you are not allowed to use `nn.MultiheadAttention` or `nn.functional.scaled_dot_product_attention`!
        #
        # Hint 1: Use `torch.reshape` to add a new axis for the attention head,
        #         which will allow you to process all attention heads in parallel.
        #
        # Hint 2: You can use `torch.transpose` to swap the order of two axes,
        #         As the attention head dimension should be next to the batch size,
        #         see the shape of the output attention weights.
        # 
        # Hint 3: `torch.bmm(matrix1, matrix2)` is useful for computing batched matrix multiplications
        #         If matrix1 has shape (B, M, N) and matrix2 has shape (B, N, P),
        #         it performs `B` matrix multiplications and outputs a tensor of shape (B, M, P). 
        #         Alternatively, `torch.einsum` should be very useful.
        #         (We really encourage you to check out the documentation of `torch.einsum`, 
        #         it can really make your life easier here.)
        
        # multiply the q,k and v with their respective weights
        # dimensions dont change here
        q = self.wq(hidden_states)
        
        # k,v are the hidden state if self attention and encoder outputs if cross attention
        if not self.is_cross_attention:
            k = self.wk(hidden_states)
            v = self.wv(hidden_states)
        else:
            # if its a cross attention block and the encoder input wasnt provided blow up
            if encoder_outputs is None:
                raise ValueError("Encodes input wasnt provided to the cross attention head")
            k = self.wk(encoder_outputs)
            v = self.wv(encoder_outputs)
        
        # split the q,k and v into Heads
        # (Batch, Seq, Dim) -> (Batch, Seq, Heads, Head size)
        batch, seq, dim = q.shape
        _, enc_seq, _ = k.shape
        new_shape = batch, -1, self.num_attention_heads, self.head_dim
        q = q.view(new_shape)
        k = k.view(new_shape)
        v = v.view(new_shape)
        
        # (Batch, Seq, Heads, Head size) -> (Batch, Heads, Seq, Head_size)
        q = q.transpose(1,2)
        k = k.transpose(1,2)
        v = v.transpose(1,2)
        
        # compute the attention scores
        # (Batch, Heads, Seq, Head_size) x (Batch, Heads, Head_size, En_Seq) -> (Batch, Heads, Seq, En_Seq)
        attention_scores = q @ k.transpose(-1,-2)
        
        # transpose to make it broadcastable with the mask
        # (Batch, Heads, Seq, En_Seq) -> (Heads, Batch, Seq, En_Seq)
        attention_scores = attention_scores.transpose(0,1)
        
        # add a dimension to the mask before applying it
        # (Batch, Seq) -> (Batch, 1, Seq)
        key_padding_mask = key_padding_mask.unsqueeze(-2)
    
        # apply mask by setting all the paddings attention to a very small number which will be 0 after softmax 
        # now all the columns of the paddings will be -1e9. which means no words will pay attention to the paddings
        attention_scores.masked_fill_(key_padding_mask == True, -1e9)
        
        # return to the original shape
        attention_scores = attention_scores.transpose(0,1)
        
        # normalize the attention
        attention_scores /= self.normalization_value
        
        # apply causal mask
        if self.is_causal_attention:
            causal_mask = self.causal_attention_mask(enc_seq,attention_scores.device)
            attention_scores = attention_scores + causal_mask
            
        # apply softmax 
        attention_scores = attention_scores.softmax(dim = -1)
        
        # compute the final output by multiplying the attention and the values
        # (Batch, Heads, Seq, Seq) x (Batch, Heads, Seq, Head_size) -> (Batch, Heads, Seq, Head_size)
        o = attention_scores @ v
        
        # transpose the output before concat
        # (Batch, Seq, Heads, Head_size)
        o = o.transpose(1,2)
        
        # concat the heads outputs
        # (Batch, Seq, Heads, Head_size) -> (Batch, Seq, Dim)
        o = o.contiguous().view(batch, seq, dim)

        return o, attention_scores

# %%
batch, seq, heads, dim = 10, 5, 2, 4 
MHA = MultiHeadAttention(dim, heads, is_causal_attention=True)
a, b = MHA.forward(torch.rand((batch, seq, dim)), torch.rand(batch, seq) > .5)
'output shape: ' +  str(a.shape) + ' attention shape: ' + str(b.shape)
# Out:
# 'output shape: torch.Size([10, 5, 4]) attention shape: torch.Size([10, 2, 5, 5])'

# %% [markdown]
# Before we move on to the other modules, you should implement a sanity check for your attention implementation:
# 1. We check the dimensions of the output of the layer and
# 2. We plot the attention weights to some toy embedding inputs.
# We assume that the last token in the encoder and the last two tokens in the decoder are pad tokens.

# %%
print("Sanity check for MultiHeadAttention")
embed_dim = 8
num_heads = 2
batch_size = 1
encoder_seq_length = 5
decoder_seq_length = 7

encoder_outputs = torch.randn(batch_size, encoder_seq_length, embed_dim)
decoder_inputs = torch.randn(batch_size, decoder_seq_length, embed_dim)

encoder_padding_mask = torch.zeros(batch_size, encoder_seq_length, dtype=torch.bool)
encoder_padding_mask[:, -1] = True # The last encoder token is a padding tokens

decoder_padding_mask = torch.zeros(batch_size, decoder_seq_length, dtype=torch.bool)
decoder_padding_mask[:, -2:] = True # The last two decoder tokens are padding token


cross_attention = MultiHeadAttention(embed_dim, num_heads, is_cross_attention=True)
causal_attention = MultiHeadAttention(embed_dim, num_heads, is_causal_attention=True)

cross_attention_out, cross_attention_weights = cross_attention(decoder_inputs, encoder_padding_mask, encoder_outputs)
causal_attention_out, causal_attention_weights = causal_attention(decoder_inputs, decoder_padding_mask)

# Make sure your outputs have the right hapes
assert cross_attention_out.shape == (batch_size, decoder_seq_length, embed_dim)
assert cross_attention_weights.shape == (batch_size, num_heads, decoder_seq_length, encoder_seq_length)
assert causal_attention_out.shape == (batch_size, decoder_seq_length, embed_dim)
assert causal_attention_weights.shape == (batch_size, num_heads, decoder_seq_length, decoder_seq_length)

# Check that the attention weights are normalized
assert torch.isclose(cross_attention_weights.sum(dim=-1), torch.tensor(1.0)).all()
assert torch.isclose(causal_attention_weights.sum(dim=-1), torch.tensor(1.0)).all()

# Check if the attention masking works
assert torch.isclose(cross_attention_weights[:,:,:,-1], torch.tensor(0.0)).all()
assert torch.isclose(causal_attention_weights[:,:,:,-2:], torch.tensor(0.0)).all()
assert torch.isclose(causal_attention_weights[:,:,2,3:], torch.tensor(0.0)).all()
print("Sanity check passed! (al3b a tofiiiii)")

import matplotlib.pyplot as plt

def plot_attention_matrix(attention_matrix, title):
    """Creates a new figure and plots the normalized attention weights as a heatmap.

    This should provide a colorbar for the scale of the heatmap and label the axes "query token position" and "key token position".
    Args:
        attention_matrix: A numpy array of shape (number_of_query_tokens, number_of_key_tokens)
        title: The title of the plot.
    """
    # TODO Implement this function
    plt.imshow(attention_matrix) 
    # Add colorbar 
    plt.colorbar() 
    plt.title(title)
    plt.xlabel("query token position") 
    plt.ylabel("key token position") 
    plt.show() 
    #raise NotImplementedError("Plotting the attention weights is not implemented yet.")

plot_attention_matrix(cross_attention_weights[0,0].detach().numpy(), "cross-attention, head 1")
plot_attention_matrix(cross_attention_weights[0,1].detach().numpy(), "cross-attention, head 2")
plot_attention_matrix(causal_attention_weights[0,0].detach().numpy(), "causal self-attention, head 1")
plot_attention_matrix(causal_attention_weights[0,1].detach().numpy(), "causal self-attention, head 2")
# Out:
# Sanity check for MultiHeadAttention
# Sanity check passed! (al3b a tofiiiii)

# %%
class TransformerEmbeddings(nn.Module):
    def __init__(self, vocab_size: int, hidden_size: int, max_sequence_length: int):
        """Defines the embedding layer with learnt positional embeddings. 
        
        This layer defines both the token embeddings and positional embeddings,
        which are added together to form the final embedding.
        
        Args:
            vocab_size: The size of the vocabulary, 
                    used to define the size of the token embedding table.
            hidden_size: The dimensionality of the embedding space for both token embeddings and positional embeddings.
            max_sequence_length: The maximum sequence length of the input sequences,
                    used to define the size of the position embedding table.
        
        Note that this implementation does not use dropout on the embeddings
        and uses learnt positional embeddings instead of sinusoidal embeddings.
        """
        super().__init__()
        
        # TODO Initialize the module and its parameters here.
        # You should use `nn.Embedding` for both token embeddings and positional embeddings
        self.tokenEmbedding = nn.Embedding(vocab_size,hidden_size)
        self.positionalEmbedding = nn.Embedding(max_sequence_length,hidden_size)
        #raise NotImplementedError("The __init__ function in TransformerEmbeddings is not implemented yet.")
    
    def compute_logits(self, decoder_output: torch.FloatTensor) -> torch.FloatTensor:
        """Computes the logits for the next token prediction given the decoder output.
        
        Args:
            decoder_output: Tensor of shape (batch_size, sequence_length, hidden_size) - the output of the decoder.
            
        Returns:
            Tensor of shape (batch_size, sequence_length, vocab_size) containing the logits for the next token prediction.
        """
        
        # TODO Implement this function
        # Hint: you can access the weight parameter matrix via .weight of an nn.Embedding module:
        # Example:
        # ```embeddings = nn.Embedding(num_embeddings, embedding_dim)
        # assert list(embeddings.weight.shape) == [num_embeddings, embedding_dim]```
        
        # torch.matmul or F.linear may also be useful here.
        return F.linear(decoder_output,self.tokenEmbedding.weight)
        
        #raise NotImplementedError("The compute_logits function in TransformerEmbeddings is not implemented yet.")
    
    def forward(self, input_ids: torch.LongTensor) -> torch.FloatTensor:
        """Computes the embeddings for the input tokens.
        
        Args:
            input_ids: Tensor of shape (batch_size, sequence_length) containing the input token ids.
        
        Returns:
            Tensor of shape (batch_size, sequence_length, hidden_size) containing
                    the sum of token embeddings and position embeddings for the input tokens.
        """
        
        # TODO Implement the forward pass of the embedding layer.
        # IMPORTANT: For full credit, you should not use python loops!
        tokenEmbedd = self.tokenEmbedding(input_ids)
        posEmbedd = self.positionalEmbedding(torch.arange(0,input_ids.size(1),dtype=torch.long,device=input_ids.device)).unsqueeze(0)
        return tokenEmbedd+posEmbedd
        #raise NotImplementedError("The forward function in TransformerEmbeddings is not implemented yet.")

# %%
class TransformerBlock(nn.Module):
    def __init__(self,
                 hidden_size: int,
                 intermediate_size: int, 
                 num_attention_heads: int, 
                 hidden_dropout_prob: float,
                 is_decoder: bool = False):
        """Defines a single Transformer block, which can be either for the encoder or the decoder.
        
        Args:
            hidden_size: The dimensionality of the input and output vectors of this layer.
            intermediate_size: The intermediate size of the feedforward layers.
            num_attention_heads: The number of attention heads.
            hidden_dropout_prob: The dropout probability for the hidden states.
            is_decoder: Whether this block is part of the decoder.
        """
        super().__init__()
        
        self.is_decoder = is_decoder
        self.self_attention = MultiHeadAttention(hidden_size, num_attention_heads, is_causal_attention=is_decoder)
        self.self_attention_layer_norm = nn.LayerNorm(hidden_size)
        
        if is_decoder:
            self.cross_attention = MultiHeadAttention(hidden_size, num_attention_heads, is_cross_attention=True)
            self.cross_attention_layer_norm = nn.LayerNorm(hidden_size)
        
        self.feedforward = nn.Sequential(
            nn.Linear(hidden_size, intermediate_size),
            nn.ReLU(),
            nn.Linear(intermediate_size, hidden_size),
            nn.Dropout(hidden_dropout_prob))
        self.feedforward_layer_norm = nn.LayerNorm(hidden_size)

    def forward(self,
                hidden_states: torch.FloatTensor,
                padding_mask: torch.BoolTensor,
                encoder_outputs: Optional[torch.FloatTensor] = None,
                encoder_padding_mask: Optional[torch.BoolTensor] = None) -> torch.FloatTensor:
        """Defines a single Transformer block, either for the encoder or the decoder.
        
        Args:
            hidden_states: Tensor of shape (batch_size, sequence_length, hidden_size) - the outputs from the previous layer.
            padding_mask: Tensor of shape (batch_size, sequence_length) indicating which tokens are padding tokens.
                    A `True` entry means that this token should be ignored for the purpose of attention.
            encoder_outputs: Optional tensor of shape (batch_size, encoder_sequence_length, hidden_size),
                    which are the output vectors of the encoder. This argument is only used by decoder blocks.
            encoder_padding_mask: Optional tensor of shape (batch_size, encoder_sequence_length) indicating
                    which encoder tokens are padding tokens. This argument is only used in decoder blocks.
                    A `True` entry means that this token should be ignored for the purpose of attention.
            
        """
        hidden_states = self.self_attention(hidden_states, padding_mask)[0] + hidden_states
        hidden_states = self.self_attention_layer_norm(hidden_states)
        
        if self.is_decoder:
            hidden_states = self.cross_attention(hidden_states, encoder_padding_mask, encoder_outputs)[0] + hidden_states
            hidden_states = self.cross_attention_layer_norm(hidden_states)
        
        hidden_states = self.feedforward(hidden_states) + hidden_states
        hidden_states = self.feedforward_layer_norm(hidden_states)
        return hidden_states

# %%
class EncoderDecoderModel(nn.Module):
    def __init__(self,
                 source_vocab_size: int,
                 target_vocab_size: int,
                 hidden_size: int,
                 intermediate_size: int,
                 num_attention_heads: int, 
                 num_encoder_layers: int,
                 num_decoder_layers: int,
                 max_sequence_length: int,
                 hidden_dropout_prob: float):
        """A encoder-decoder transformer model which can be used for NMT.
        
        Args:
            source_vocab_size: The size of the source vocabulary.
            target_vocab_size: The size of the target vocabulary.
            hidden_size: The dimensionality of all input and output embeddings.
            intermediate_size: The intermediate size in the feedforward layers.
            num_attention_heads: The number of attention heads in each multi-head attention modules.
            num_encoder_layers: The number of transformer blocks in the encoder.
            num_decoder_layers: The number of transformer blocks in the decoder.
            max_sequence_length: The maximum sequence length that this model can handle.
            hidden_dropout_prob: The dropout probability in the hidden state in each block.
        """
        
        super().__init__()
        # TODO Register the input embedding modules and the encoder and decoder blocks.
        # You should use the TransformerBlock and TransformerEmbeddings sub-modules.
        #
        # Hint: Check out `nn.ModuleList` to register a variable number of sub-modules.
        self.srcEmbedding = TransformerEmbeddings(source_vocab_size,hidden_size,max_sequence_length)
        self.targetEmbedding = TransformerEmbeddings(target_vocab_size,hidden_size,max_sequence_length)
        self.encoders = nn.ModuleList([TransformerBlock(hidden_size,intermediate_size,num_attention_heads,hidden_dropout_prob,False) for i in range(num_encoder_layers)])
        self.decoders = nn.ModuleList([TransformerBlock(hidden_size,intermediate_size,num_attention_heads,hidden_dropout_prob,True) for i in range(num_decoder_layers)])
        #raise NotImplementedError("The __init__ function is not implemented yet.")
        
    def forward_encoder(self, input_ids: torch.LongTensor, padding_mask: torch.BoolTensor) -> torch.FloatTensor:
        """Implement the forward pass of the encoder.

        Args:
            input_ids: tensor of shape (batch_size, sequence_length) containing the input token ids to the encoder.
            padding_mask: tensor of shape (batch_size, sequence_length) indicating which encoder tokens are padding tokens (`True`)
                    and should be ignored in self-attention computations.
                    
        Returns:
            Tensor of shape (batch_size, sequence_length, hidden_size) containing the output embeddings of the encoder.
        """
        x = self.srcEmbedding(input_ids)
        # TODO Implement this function
        for encoder in self.encoders:
            x = encoder(x,padding_mask)
        return x
        #raise NotImplementedError("The forward_encoder function is not implemented yet.")
    
    def forward_decoder(self,
                        input_ids: torch.LongTensor,
                        padding_mask: torch.BoolTensor,
                        encoder_outputs: torch.FloatTensor,
                        encoder_padding_mask: torch.BoolTensor) -> torch.FloatTensor:
        """Implement the forward pass of the decoder.

        Args:
            input_ids: Tensor of shape (batch_size, sequence_length) containing the input token ids to the decoder.
            padding_mask: Tensor of shape (batch_size, sequence_length) indicating which decoder tokens are padding tokens (`True`)
                    and should be ignored in self-attention computations.
            encoder_outputs: Tensor of shape (batch_size, encoder_sequence_length, hidden_size) containing the output embeddings of the encoder.
            encoder_padding_mask: Tensor of shape (batch_size, encoder_sequence_length) indicating which encoder tokens are padding tokens (`True`)
                    and should be ignored in cross-attention computations.
                    
        Returns:
            Tensor of shape (batch_size, sequence_length, target_vocabulary_size) 
            containing the logits for predicting the next token in the target sequence.
        """
        
        # TODO Implement this function
        x = self.targetEmbedding(input_ids)
        for decoder in self.decoders:
            x = decoder(x,padding_mask,encoder_outputs,encoder_padding_mask)
        return self.targetEmbedding.compute_logits(x)
        #raise NotImplementedError("The forward_decoder function has to be implemented.")
    
    def forward(self, encoder_input_ids, encoder_padding_mask, decoder_input_ids, decoder_padding_mask):
        encoder_outputs = self.forward_encoder(encoder_input_ids, encoder_padding_mask)
        decoder_logits = self.forward_decoder(decoder_input_ids, decoder_padding_mask, encoder_outputs, encoder_padding_mask)
        return decoder_logits

# %% [markdown]
# ## Train the model
#
# In this section, we train the seq2seq model on the parallel tokenized corpus.
# Before you start training models, you should implement and test the model and its sub-modules, especially the attention.
#
# First, we implement a `collate` function, which takes a list of examples from the dataset and forms a batch,
# consisting of padded encoder and decoder input ids, as well as encoder and decoder padding masks.

# %%
def collate_fn(examples: List[Dict[str, List[int]]]) -> Dict[str, torch.Tensor]:
    """Collates a list of variable length sequences from the dataset into a batch of pytorch tensors with padding."""
    
    encoder_sequence_length = max(len(example["encoder_input_ids"]) for example in examples)
    decoder_sequence_length = max(len(example["decoder_input_ids"]) for example in examples)
    batch_size = len(examples)
    
    encoder_input_ids = torch.full((batch_size, encoder_sequence_length),
                                   fill_value=source_tokenizer.pad_token_id,
                                   dtype=torch.int64)
    encoder_padding_mask = torch.ones((batch_size, encoder_sequence_length),
                                      dtype=torch.bool)
    
    decoder_input_ids = torch.full((batch_size, decoder_sequence_length),
                                   fill_value=target_tokenizer.pad_token_id,
                                   dtype=torch.int64)
    decoder_padding_mask = torch.ones((batch_size, decoder_sequence_length),
                                      dtype=torch.bool)
    
    for i, example in enumerate(examples):
        encoder_input_ids[i, :len(example["encoder_input_ids"])] = torch.tensor(example["encoder_input_ids"])
        encoder_padding_mask[i, :len(example["encoder_input_ids"])] = False
        
        decoder_input_ids[i, :len(example["decoder_input_ids"])] = torch.tensor(example["decoder_input_ids"])
        decoder_padding_mask[i, :len(example["decoder_input_ids"])] = False    

    return {"encoder_input_ids": encoder_input_ids,
            "encoder_padding_mask": encoder_padding_mask,
            "decoder_input_ids": decoder_input_ids,
            "decoder_padding_mask": decoder_padding_mask}

# %% [markdown]
# Next, we provide a simple training loop.

# %%
import time
import math

def compute_loss_per_token(model, batch):
    logits = model(**batch)
    
    valid_label_mask = ~(batch["decoder_padding_mask"][:,1:])
    labels = batch["decoder_input_ids"][:,1:][valid_label_mask]
    logits = logits[:,:-1][valid_label_mask]
    
    return F.cross_entropy(logits, labels, reduction='none') 
    

def evaluate_perplexity(model, dataset, batch_size=32, device="cpu"):
    model.eval()

    dev_loader = torch.utils.data.DataLoader(
        dataset, batch_size=batch_size, shuffle=False, collate_fn=collate_fn)
    
    num_tokens = loss_sum = 0

    # no_grad() signals backend to throw away all gradients
    with torch.no_grad():
        for batch in dev_loader:
            # Move tensors in batch to device
            for key in batch:
                batch[key] = batch[key].to(device)
                
            token_losses = compute_loss_per_token(model, batch)

            loss_sum += token_losses.sum()
            num_tokens += token_losses.numel()

        dev_ppl = (loss_sum / num_tokens).exp().cpu().item()
    return dev_ppl

    
def train(model, training_dataset, validation_dataset,
          batch_size=32, lr=1e-3, max_epoch=10, log_every=10, valid_niter=100,
          model_path="model.pt"):
    model.train()

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print('Use device: %s' % device)

    model = model.to(device)
    
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    epoch = global_step = loss_sum = num_tokens = num_examples = 0
    best_valid_perplexity = float('inf')
    train_time = begin_time = time.time()
    print('Beginning maximum likelihood training')
    

    while True:
        train_loader = torch.utils.data.DataLoader(
            training_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)
        epoch += 1
        batches_per_epoch = len(train_loader) 
        for i, batch in enumerate(train_loader):
            global_step += 1
            
            # Move tensors in batch to device
            for key in batch:
                batch[key] = batch[key].to(device)
                
            optimizer.zero_grad()
            
            token_losses = compute_loss_per_token(model, batch)
            total_loss = token_losses.sum()
            
            loss = total_loss / batch_size
            loss.backward()
            
            optimizer.step()

            loss_sum += total_loss.cpu().item()
            num_tokens += token_losses.numel()
            num_examples += batch_size

            if global_step % log_every == 0:
                average_loss = loss_sum / num_examples
                average_ppl = math.exp(loss_sum / num_tokens)
                print(f"epoch {epoch} ({i}/{batches_per_epoch}) | step {global_step} | "
                      f"avg_nll={average_loss:.2f} avg_ppl={average_ppl:.2f} "
                      f"speed={num_tokens / (time.time() - train_time):.2f} words/sec "
                      f"time_elapsed={time.time() - begin_time:.2f} sec")

                train_time = time.time()
                loss_sum = num_tokens = num_examples = 0.0

            if global_step % valid_niter == 0:
                print('Begin validation ...')
                dev_perplexity = evaluate_perplexity(model, validation_dataset, batch_size=batch_size, device=device)
                
                print(f"validation: step {global_step} | dev_ppl={dev_perplexity}")

                if dev_perplexity < best_valid_perplexity:
                    best_valid_perplexity = dev_perplexity
                    print(f"epoch {epoch} step {global_step}: save currently the best model to '{model_path}'")
                    torch.save(model.state_dict(), model_path)
                    torch.save(optimizer.state_dict(), model_path + '.optim')
                model.train()    
            
        if epoch == max_epoch:
            print('Reached maximum number of epochs')
            break

# %% [markdown]
# Let's train a relatively small model architecture for 15 epochs.
# With a reasonable implementation, this should take about 16 minutes on CPU / 3 minutes on GPU and we should achieve a validation perplexity of below 10!

# %%
# Set a random seed, so you obtain the same output model if you run this cell again. 
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)

model = EncoderDecoderModel(
    source_vocab_size=source_tokenizer.vocab_size,
    target_vocab_size=target_tokenizer.vocab_size,
    hidden_size=32, 
    intermediate_size=32 * 4, 
    num_attention_heads=4, 
    num_encoder_layers=3, 
    num_decoder_layers=3, 
    max_sequence_length=32, 
    hidden_dropout_prob=0.1,
    )

print("Model architecture:", model)
print("Total number of trainable model parameters:", sum(p.numel() for p in model.parameters() if p.requires_grad))

train(model, tokenized_datasets["train"], tokenized_datasets["validation"],
      max_epoch=15, model_path="model.pt")
# Out:
# Model architecture: EncoderDecoderModel(
#   (srcEmbedding): TransformerEmbeddings(
#     (tokenEmbedding): Embedding(3200, 32)
#     (positionalEmbedding): Embedding(32, 32)
#   )
#   (targetEmbedding): TransformerEmbeddings(
#     (tokenEmbedding): Embedding(3200, 32)
#     (positionalEmbedding): Embedding(32, 32)
#   )
#   (encoders): ModuleList(
#     (0-2): 3 x TransformerBlock(
#       (self_attention): MultiHeadAttention(
#         (wq): Linear(in_features=32, out_features=32, bias=True)
#         (wk): Linear(in_features=32, out_features=32, bias=True)
#         (wv): Linear(in_features=32, out_features=32, bias=True)
#       )
#       (self_attention_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#       (feedforward): Sequential(
#         (0): Linear(in_features=32, out_features=128, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=128, out_features=32, bias=True)
#         (3): Dropout(p=0.1, inplace=False)
#       )
#       (feedforward_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (decoders): ModuleList(
#     (0-2): 3 x TransformerBlock(
#       (self_attention): MultiHeadAttention(
#         (wq): Linear(in_features=32, out_features=32, bias=True)
#         (wk): Linear(in_features=32, out_features=32, bias=True)
#         (wv): Linear(in_features=32, out_features=32, bias=True)
#       )
#       (self_attention_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#       (cross_attention): MultiHeadAttention(
#         (wq): Linear(in_features=32, out_features=32, bias=True)
#         (wk): Linear(in_features=32, out_features=32, bias=True)
#         (wv): Linear(in_features=32, out_features=32, bias=True)
#       )
#       (cross_attention_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#       (feedforward): Sequential(
#         (0): Linear(in_features=32, out_features=128, bias=True)
#         (1): ReLU()
#         (2): Linear(in_features=128, out_features=32, bias=True)
#         (3): Dropout(p=0.1, inplace=False)
#       )
#       (feedforward_layer_norm): LayerNorm((32,), eps=1e-05, elementwise_affine=True)
#     )
#   )
# )
# Total number of trainable model parameters: 286432
# Use device: cuda
# Beginning maximum likelihood training
# epoch 1 (9/272) | step 10 | avg_nll=118.49 avg_ppl=12893431.33 speed=8479.93 words/sec time_elapsed=0.27 sec
# epoch 1 (19/272) | step 20 | avg_nll=88.12 avg_ppl=195954.10 speed=13320.53 words/sec time_elapsed=0.45 sec
# epoch 1 (29/272) | step 30 | avg_nll=80.11 avg_ppl=64707.86 speed=13199.38 words/sec time_elapsed=0.62 sec
# epoch 1 (39/272) | step 40 | avg_nll=71.62 avg_ppl=21269.56 speed=13383.56 words/sec time_elapsed=0.79 sec
# epoch 1 (49/272) | step 50 | avg_nll=67.19 avg_ppl=9898.77 speed=13302.46 words/sec time_elapsed=0.97 sec
# epoch 1 (59/272) | step 60 | avg_nll=59.32 avg_ppl=3865.21 speed=12474.90 words/sec time_elapsed=1.15 sec
# epoch 1 (69/272) | step 70 | avg_nll=53.29 avg_ppl=1580.87 speed=12656.68 words/sec time_elapsed=1.34 sec
# epoch 1 (79/272) | step 80 | avg_nll=51.98 avg_ppl=1210.93 speed=13029.64 words/sec time_elapsed=1.52 sec
# epoch 1 (89/272) | step 90 | avg_nll=49.03 avg_ppl=865.39 speed=13042.41 words/sec time_elapsed=1.69 sec
# epoch 1 (99/272) | step 100 | avg_nll=47.68 avg_ppl=684.24 speed=12481.39 words/sec time_elapsed=1.88 sec
# Begin validation ...
# validation: step 100 | dev_ppl=420.22509765625
# epoch 1 step 100: save currently the best model to 'model.pt'
# epoch 1 (109/272) | step 110 | avg_nll=44.17 avg_ppl=462.93 speed=7328.60 words/sec time_elapsed=2.20 sec
# epoch 1 (119/272) | step 120 | avg_nll=43.12 avg_ppl=377.91 speed=13060.14 words/sec time_elapsed=2.37 sec
# epoch 1 (129/272) | step 130 | avg_nll=41.40 avg_ppl=315.01 speed=13512.20 words/sec time_elapsed=2.55 sec
# epoch 1 (139/272) | step 140 | avg_nll=40.49 avg_ppl=287.10 speed=12597.11 words/sec time_elapsed=2.73 sec
# epoch 1 (149/272) | step 150 | avg_nll=40.37 avg_ppl=249.95 speed=13420.95 words/sec time_elapsed=2.90 sec
# epoch 1 (159/272) | step 160 | avg_nll=38.66 avg_ppl=199.18 speed=13441.88 words/sec time_elapsed=3.08 sec
# epoch 1 (169/272) | step 170 | avg_nll=37.76 avg_ppl=184.95 speed=13599.43 words/sec time_elapsed=3.25 sec
# epoch 1 (179/272) | step 180 | avg_nll=34.25 avg_ppl=123.93 speed=13140.16 words/sec time_elapsed=3.42 sec
# epoch 1 (189/272) | step 190 | avg_nll=36.11 avg_ppl=144.10 speed=13646.32 words/sec time_elapsed=3.59 sec
# epoch 1 (199/272) | step 200 | avg_nll=34.99 avg_ppl=124.43 speed=13215.04 words/sec time_elapsed=3.77 sec
# Begin validation ...
# validation: step 200 | dev_ppl=98.02567291259766
# epoch 1 step 200: save currently the best model to 'model.pt'
# epoch 1 (209/272) | step 210 | avg_nll=35.12 avg_ppl=127.25 speed=7430.52 words/sec time_elapsed=4.08 sec
# epoch 1 (219/272) | step 220 | avg_nll=34.35 avg_ppl=109.03 speed=13539.67 words/sec time_elapsed=4.25 sec
# epoch 1 (229/272) | step 230 | avg_nll=32.84 avg_ppl=93.03 speed=13067.21 words/sec time_elapsed=4.43 sec
# epoch 1 (239/272) | step 240 | avg_nll=32.96 avg_ppl=95.54 speed=13245.89 words/sec time_elapsed=4.60 sec
# epoch 1 (249/272) | step 250 | avg_nll=32.00 avg_ppl=81.19 speed=12681.12 words/sec time_elapsed=4.79 sec
# epoch 1 (259/272) | step 260 | avg_nll=30.19 avg_ppl=67.82 speed=12364.73 words/sec time_elapsed=4.97 sec
# epoch 1 (269/272) | step 270 | avg_nll=30.47 avg_ppl=67.58 speed=13186.37 words/sec time_elapsed=5.15 sec
# epoch 2 (7/272) | step 280 | avg_nll=29.24 avg_ppl=57.91 speed=13189.60 words/sec time_elapsed=5.32 sec
# epoch 2 (17/272) | step 290 | avg_nll=29.08 avg_ppl=56.18 speed=13179.66 words/sec time_elapsed=5.50 sec
# epoch 2 (27/272) | step 300 | avg_nll=30.17 avg_ppl=65.21 speed=13224.38 words/sec time_elapsed=5.67 sec
# Begin validation ...
# validation: step 300 | dev_ppl=50.5711555480957
# epoch 2 step 300: save currently the best model to 'model.pt'
# epoch 2 (37/272) | step 310 | avg_nll=28.33 avg_ppl=50.23 speed=6504.08 words/sec time_elapsed=6.03 sec
# epoch 2 (47/272) | step 320 | avg_nll=29.83 avg_ppl=58.28 speed=12817.90 words/sec time_elapsed=6.21 sec
# epoch 2 (57/272) | step 330 | avg_nll=28.57 avg_ppl=50.94 speed=13193.24 words/sec time_elapsed=6.39 sec
# epoch 2 (67/272) | step 340 | avg_nll=28.26 avg_ppl=48.81 speed=13461.18 words/sec time_elapsed=6.56 sec
# epoch 2 (77/272) | step 350 | avg_nll=27.51 avg_ppl=46.59 speed=12915.03 words/sec time_elapsed=6.74 sec
# epoch 2 (87/272) | step 360 | avg_nll=28.82 avg_ppl=52.69 speed=13282.46 words/sec time_elapsed=6.91 sec
# epoch 2 (97/272) | step 370 | avg_nll=28.10 avg_ppl=47.05 speed=12867.01 words/sec time_elapsed=7.09 sec
# epoch 2 (107/272) | step 380 | avg_nll=28.00 avg_ppl=47.50 speed=13673.09 words/sec time_elapsed=7.26 sec
# epoch 2 (117/272) | step 390 | avg_nll=26.44 avg_ppl=38.19 speed=13184.55 words/sec time_elapsed=7.44 sec
# epoch 2 (127/272) | step 400 | avg_nll=26.45 avg_ppl=38.61 speed=12856.67 words/sec time_elapsed=7.62 sec
# Begin validation ...
# validation: step 400 | dev_ppl=35.586669921875
# epoch 2 step 400: save currently the best model to 'model.pt'
# epoch 2 (137/272) | step 410 | avg_nll=24.94 avg_ppl=34.22 speed=7358.73 words/sec time_elapsed=7.93 sec
# epoch 2 (147/272) | step 420 | avg_nll=27.95 avg_ppl=44.51 speed=13591.74 words/sec time_elapsed=8.10 sec
# epoch 2 (157/272) | step 430 | avg_nll=26.39 avg_ppl=38.96 speed=13280.71 words/sec time_elapsed=8.28 sec
# epoch 2 (167/272) | step 440 | avg_nll=24.76 avg_ppl=32.18 speed=13067.21 words/sec time_elapsed=8.45 sec
# epoch 2 (177/272) | step 450 | avg_nll=24.97 avg_ppl=32.27 speed=13153.45 words/sec time_elapsed=8.62 sec
# epoch 2 (187/272) | step 460 | avg_nll=25.05 avg_ppl=32.94 speed=12862.87 words/sec time_elapsed=8.80 sec
# epoch 2 (197/272) | step 470 | avg_nll=26.08 avg_ppl=36.51 speed=13191.39 words/sec time_elapsed=8.98 sec
# epoch 2 (207/272) | step 480 | avg_nll=26.06 avg_ppl=34.42 speed=12098.93 words/sec time_elapsed=9.17 sec
# epoch 2 (217/272) | step 490 | avg_nll=24.95 avg_ppl=31.97 speed=12954.35 words/sec time_elapsed=9.35 sec
# epoch 2 (227/272) | step 500 | avg_nll=25.49 avg_ppl=34.35 speed=12716.78 words/sec time_elapsed=9.53 sec
# Begin validation ...
# validation: step 500 | dev_ppl=29.027162551879883
# epoch 2 step 500: save currently the best model to 'model.pt'
# epoch 2 (237/272) | step 510 | avg_nll=25.02 avg_ppl=32.19 speed=7489.67 words/sec time_elapsed=9.84 sec
# epoch 2 (247/272) | step 520 | avg_nll=25.44 avg_ppl=32.41 speed=13372.71 words/sec time_elapsed=10.02 sec
# epoch 2 (257/272) | step 530 | avg_nll=25.72 avg_ppl=32.78 speed=12822.78 words/sec time_elapsed=10.20 sec
# epoch 2 (267/272) | step 540 | avg_nll=24.21 avg_ppl=28.38 speed=13399.76 words/sec time_elapsed=10.37 sec
# epoch 3 (5/272) | step 550 | avg_nll=24.72 avg_ppl=30.15 speed=13092.17 words/sec time_elapsed=10.55 sec
# epoch 3 (15/272) | step 560 | avg_nll=23.99 avg_ppl=28.44 speed=13154.85 words/sec time_elapsed=10.72 sec
# epoch 3 (25/272) | step 570 | avg_nll=23.66 avg_ppl=25.99 speed=13230.11 words/sec time_elapsed=10.90 sec
# epoch 3 (35/272) | step 580 | avg_nll=23.83 avg_ppl=26.71 speed=13366.40 words/sec time_elapsed=11.07 sec
# epoch 3 (45/272) | step 590 | avg_nll=24.20 avg_ppl=27.45 speed=12517.90 words/sec time_elapsed=11.26 sec
# epoch 3 (55/272) | step 600 | avg_nll=24.23 avg_ppl=27.57 speed=13567.70 words/sec time_elapsed=11.43 sec
# Begin validation ...
# validation: step 600 | dev_ppl=25.183996200561523
# epoch 3 step 600: save currently the best model to 'model.pt'
# epoch 3 (65/272) | step 610 | avg_nll=24.05 avg_ppl=26.55 speed=7679.20 words/sec time_elapsed=11.74 sec
# epoch 3 (75/272) | step 620 | avg_nll=22.89 avg_ppl=25.09 speed=10213.43 words/sec time_elapsed=11.96 sec
# epoch 3 (85/272) | step 630 | avg_nll=23.77 avg_ppl=25.82 speed=10543.04 words/sec time_elapsed=12.18 sec
# epoch 3 (95/272) | step 640 | avg_nll=23.22 avg_ppl=25.34 speed=9244.45 words/sec time_elapsed=12.43 sec
# epoch 3 (105/272) | step 650 | avg_nll=23.03 avg_ppl=24.38 speed=8817.63 words/sec time_elapsed=12.69 sec
# epoch 3 (115/272) | step 660 | avg_nll=23.64 avg_ppl=25.60 speed=8673.28 words/sec time_elapsed=12.96 sec
# epoch 3 (125/272) | step 670 | avg_nll=22.81 avg_ppl=22.83 speed=9830.73 words/sec time_elapsed=13.20 sec
# epoch 3 (135/272) | step 680 | avg_nll=22.85 avg_ppl=24.27 speed=12054.44 words/sec time_elapsed=13.39 sec
# epoch 3 (145/272) | step 690 | avg_nll=23.71 avg_ppl=25.88 speed=13021.73 words/sec time_elapsed=13.57 sec
# epoch 3 (155/272) | step 700 | avg_nll=24.15 avg_ppl=26.80 speed=13146.71 words/sec time_elapsed=13.75 sec
# Begin validation ...
# validation: step 700 | dev_ppl=22.52381706237793
# epoch 3 step 700: save currently the best model to 'model.pt'
# epoch 3 (165/272) | step 710 | avg_nll=23.06 avg_ppl=24.45 speed=7138.39 words/sec time_elapsed=14.07 sec
# epoch 3 (175/272) | step 720 | avg_nll=22.40 avg_ppl=23.59 speed=11544.15 words/sec time_elapsed=14.27 sec
# epoch 3 (185/272) | step 730 | avg_nll=22.19 avg_ppl=21.93 speed=11416.50 words/sec time_elapsed=14.47 sec
# epoch 3 (195/272) | step 740 | avg_nll=22.42 avg_ppl=22.25 speed=9790.51 words/sec time_elapsed=14.71 sec
# epoch 3 (205/272) | step 750 | avg_nll=22.56 avg_ppl=22.55 speed=8772.12 words/sec time_elapsed=14.97 sec
# epoch 3 (215/272) | step 760 | avg_nll=22.31 avg_ppl=22.57 speed=9533.48 words/sec time_elapsed=15.21 sec
# epoch 3 (225/272) | step 770 | avg_nll=22.73 avg_ppl=22.73 speed=9621.29 words/sec time_elapsed=15.45 sec
# epoch 3 (235/272) | step 780 | avg_nll=22.09 avg_ppl=21.54 speed=11153.45 words/sec time_elapsed=15.66 sec
# epoch 3 (245/272) | step 790 | avg_nll=21.72 avg_ppl=20.24 speed=10195.43 words/sec time_elapsed=15.89 sec
# epoch 3 (255/272) | step 800 | avg_nll=22.05 avg_ppl=20.63 speed=10210.51 words/sec time_elapsed=16.11 sec
# Begin validation ...
# validation: step 800 | dev_ppl=20.595367431640625
# epoch 3 step 800: save currently the best model to 'model.pt'
# epoch 3 (265/272) | step 810 | avg_nll=22.63 avg_ppl=22.43 speed=5587.30 words/sec time_elapsed=16.53 sec
# epoch 4 (3/272) | step 820 | avg_nll=22.54 avg_ppl=22.31 speed=9965.92 words/sec time_elapsed=16.76 sec
# epoch 4 (13/272) | step 830 | avg_nll=21.62 avg_ppl=19.68 speed=9421.12 words/sec time_elapsed=17.01 sec
# epoch 4 (23/272) | step 840 | avg_nll=21.20 avg_ppl=19.74 speed=9126.51 words/sec time_elapsed=17.26 sec
# epoch 4 (33/272) | step 850 | avg_nll=22.11 avg_ppl=20.95 speed=9584.49 words/sec time_elapsed=17.50 sec
# epoch 4 (43/272) | step 860 | avg_nll=20.98 avg_ppl=19.23 speed=9093.53 words/sec time_elapsed=17.75 sec
# epoch 4 (53/272) | step 870 | avg_nll=20.39 avg_ppl=18.00 speed=11538.77 words/sec time_elapsed=17.95 sec
# epoch 4 (63/272) | step 880 | avg_nll=21.27 avg_ppl=19.37 speed=9702.53 words/sec time_elapsed=18.18 sec
# epoch 4 (73/272) | step 890 | avg_nll=21.33 avg_ppl=18.99 speed=9624.28 words/sec time_elapsed=18.43 sec
# epoch 4 (83/272) | step 900 | avg_nll=21.65 avg_ppl=20.17 speed=9250.79 words/sec time_elapsed=18.67 sec
# Begin validation ...
# validation: step 900 | dev_ppl=19.105607986450195
# epoch 4 step 900: save currently the best model to 'model.pt'
# epoch 4 (93/272) | step 910 | avg_nll=21.49 avg_ppl=19.54 speed=6606.99 words/sec time_elapsed=19.02 sec
# epoch 4 (103/272) | step 920 | avg_nll=21.00 avg_ppl=18.51 speed=8985.31 words/sec time_elapsed=19.28 sec
# epoch 4 (113/272) | step 930 | avg_nll=21.08 avg_ppl=18.59 speed=11183.91 words/sec time_elapsed=19.49 sec
# epoch 4 (123/272) | step 940 | avg_nll=22.20 avg_ppl=21.19 speed=10137.64 words/sec time_elapsed=19.72 sec
# epoch 4 (133/272) | step 950 | avg_nll=22.78 avg_ppl=21.45 speed=10857.82 words/sec time_elapsed=19.94 sec
# epoch 4 (143/272) | step 960 | avg_nll=19.93 avg_ppl=16.32 speed=10790.94 words/sec time_elapsed=20.15 sec
# epoch 4 (153/272) | step 970 | avg_nll=21.23 avg_ppl=18.75 speed=9580.69 words/sec time_elapsed=20.39 sec
# epoch 4 (163/272) | step 980 | avg_nll=20.93 avg_ppl=17.75 speed=9627.72 words/sec time_elapsed=20.63 sec
# epoch 4 (173/272) | step 990 | avg_nll=20.24 avg_ppl=16.49 speed=10548.80 words/sec time_elapsed=20.85 sec
# epoch 4 (183/272) | step 1000 | avg_nll=22.13 avg_ppl=20.19 speed=9223.53 words/sec time_elapsed=21.11 sec
# Begin validation ...
# validation: step 1000 | dev_ppl=18.14405632019043
# epoch 4 step 1000: save currently the best model to 'model.pt'
# epoch 4 (193/272) | step 1010 | avg_nll=20.34 avg_ppl=17.46 speed=5872.93 words/sec time_elapsed=21.49 sec
# epoch 4 (203/272) | step 1020 | avg_nll=21.28 avg_ppl=18.90 speed=10159.95 words/sec time_elapsed=21.72 sec
# epoch 4 (213/272) | step 1030 | avg_nll=22.02 avg_ppl=19.83 speed=9069.58 words/sec time_elapsed=21.98 sec
# epoch 4 (223/272) | step 1040 | avg_nll=21.19 avg_ppl=18.58 speed=10624.79 words/sec time_elapsed=22.20 sec
# epoch 4 (233/272) | step 1050 | avg_nll=21.20 avg_ppl=18.50 speed=11248.01 words/sec time_elapsed=22.41 sec
# epoch 4 (243/272) | step 1060 | avg_nll=21.38 avg_ppl=18.91 speed=10320.64 words/sec time_elapsed=22.63 sec
# epoch 4 (253/272) | step 1070 | avg_nll=20.63 avg_ppl=17.18 speed=9880.94 words/sec time_elapsed=22.87 sec
# epoch 4 (263/272) | step 1080 | avg_nll=22.15 avg_ppl=19.96 speed=9221.41 words/sec time_elapsed=23.12 sec
# epoch 5 (1/272) | step 1090 | avg_nll=21.39 avg_ppl=18.65 speed=9585.77 words/sec time_elapsed=23.37 sec
# epoch 5 (11/272) | step 1100 | avg_nll=20.56 avg_ppl=17.26 speed=9168.03 words/sec time_elapsed=23.62 sec
# Begin validation ...
# validation: step 1100 | dev_ppl=16.91802215576172
# epoch 5 step 1100: save currently the best model to 'model.pt'
# epoch 5 (21/272) | step 1110 | avg_nll=20.68 avg_ppl=16.66 speed=5741.05 words/sec time_elapsed=24.03 sec
# epoch 5 (31/272) | step 1120 | avg_nll=20.57 avg_ppl=16.94 speed=10539.09 words/sec time_elapsed=24.25 sec
# epoch 5 (41/272) | step 1130 | avg_nll=20.30 avg_ppl=16.82 speed=10242.79 words/sec time_elapsed=24.48 sec
# epoch 5 (51/272) | step 1140 | avg_nll=20.67 avg_ppl=16.87 speed=9760.83 words/sec time_elapsed=24.72 sec
# epoch 5 (61/272) | step 1150 | avg_nll=19.03 avg_ppl=14.54 speed=9768.01 words/sec time_elapsed=24.95 sec
# epoch 5 (71/272) | step 1160 | avg_nll=19.67 avg_ppl=15.79 speed=8738.96 words/sec time_elapsed=25.21 sec
# epoch 5 (81/272) | step 1170 | avg_nll=20.37 avg_ppl=16.47 speed=9170.34 words/sec time_elapsed=25.46 sec
# epoch 5 (91/272) | step 1180 | avg_nll=19.83 avg_ppl=15.26 speed=8990.61 words/sec time_elapsed=25.72 sec
# epoch 5 (101/272) | step 1190 | avg_nll=20.27 avg_ppl=16.39 speed=8876.75 words/sec time_elapsed=25.98 sec
# epoch 5 (111/272) | step 1200 | avg_nll=18.60 avg_ppl=14.17 speed=9147.27 words/sec time_elapsed=26.23 sec
# Begin validation ...
# validation: step 1200 | dev_ppl=16.27529525756836
# epoch 5 step 1200: save currently the best model to 'model.pt'
# epoch 5 (121/272) | step 1210 | avg_nll=21.01 avg_ppl=17.56 speed=6554.98 words/sec time_elapsed=26.59 sec
# epoch 5 (131/272) | step 1220 | avg_nll=19.92 avg_ppl=15.63 speed=9642.60 words/sec time_elapsed=26.83 sec
# epoch 5 (141/272) | step 1230 | avg_nll=18.98 avg_ppl=14.45 speed=9324.96 words/sec time_elapsed=27.07 sec
# epoch 5 (151/272) | step 1240 | avg_nll=21.70 avg_ppl=19.01 speed=8847.10 words/sec time_elapsed=27.34 sec
# epoch 5 (161/272) | step 1250 | avg_nll=21.63 avg_ppl=18.51 speed=10198.27 words/sec time_elapsed=27.57 sec
# epoch 5 (171/272) | step 1260 | avg_nll=20.57 avg_ppl=16.19 speed=8869.83 words/sec time_elapsed=27.84 sec
# epoch 5 (181/272) | step 1270 | avg_nll=20.97 avg_ppl=17.01 speed=9584.91 words/sec time_elapsed=28.08 sec
# epoch 5 (191/272) | step 1280 | avg_nll=20.98 avg_ppl=17.27 speed=9699.65 words/sec time_elapsed=28.33 sec
# epoch 5 (201/272) | step 1290 | avg_nll=19.26 avg_ppl=14.50 speed=10195.43 words/sec time_elapsed=28.55 sec
# epoch 5 (211/272) | step 1300 | avg_nll=18.42 avg_ppl=13.82 speed=8943.46 words/sec time_elapsed=28.80 sec
# Begin validation ...
# validation: step 1300 | dev_ppl=16.01166534423828
# epoch 5 step 1300: save currently the best model to 'model.pt'
# epoch 5 (221/272) | step 1310 | avg_nll=20.09 avg_ppl=15.63 speed=6395.05 words/sec time_elapsed=29.17 sec
# epoch 5 (231/272) | step 1320 | avg_nll=19.87 avg_ppl=15.29 speed=11361.10 words/sec time_elapsed=29.38 sec
# epoch 5 (241/272) | step 1330 | avg_nll=19.27 avg_ppl=14.65 speed=10494.80 words/sec time_elapsed=29.59 sec
# epoch 5 (251/272) | step 1340 | avg_nll=21.03 avg_ppl=17.69 speed=10614.56 words/sec time_elapsed=29.81 sec
# epoch 5 (261/272) | step 1350 | avg_nll=19.02 avg_ppl=14.55 speed=11873.55 words/sec time_elapsed=30.01 sec
# epoch 5 (271/272) | step 1360 | avg_nll=19.41 avg_ppl=15.50 speed=12027.02 words/sec time_elapsed=30.19 sec
# epoch 6 (9/272) | step 1370 | avg_nll=18.97 avg_ppl=14.22 speed=13009.07 words/sec time_elapsed=30.37 sec
# epoch 6 (19/272) | step 1380 | avg_nll=19.98 avg_ppl=15.37 speed=12626.85 words/sec time_elapsed=30.56 sec
# epoch 6 (29/272) | step 1390 | avg_nll=18.14 avg_ppl=12.96 speed=10890.18 words/sec time_elapsed=30.76 sec
# epoch 6 (39/272) | step 1400 | avg_nll=19.24 avg_ppl=14.26 speed=13223.02 words/sec time_elapsed=30.94 sec
# Begin validation ...
# validation: step 1400 | dev_ppl=15.516289710998535
# epoch 6 step 1400: save currently the best model to 'model.pt'
# epoch 6 (49/272) | step 1410 | avg_nll=19.19 avg_ppl=14.39 speed=5758.39 words/sec time_elapsed=31.34 sec
# epoch 6 (59/272) | step 1420 | avg_nll=18.50 avg_ppl=13.58 speed=8071.85 words/sec time_elapsed=31.62 sec
# epoch 6 (69/272) | step 1430 | avg_nll=19.29 avg_ppl=14.81 speed=9350.86 words/sec time_elapsed=31.86 sec
# epoch 6 (79/272) | step 1440 | avg_nll=18.59 avg_ppl=13.29 speed=9922.33 words/sec time_elapsed=32.10 sec
# epoch 6 (89/272) | step 1450 | avg_nll=19.53 avg_ppl=14.80 speed=8903.05 words/sec time_elapsed=32.36 sec
# epoch 6 (99/272) | step 1460 | avg_nll=18.90 avg_ppl=13.38 speed=9503.98 words/sec time_elapsed=32.60 sec
# epoch 6 (109/272) | step 1470 | avg_nll=19.24 avg_ppl=13.91 speed=10690.50 words/sec time_elapsed=32.82 sec
# epoch 6 (119/272) | step 1480 | avg_nll=19.65 avg_ppl=14.79 speed=9005.27 words/sec time_elapsed=33.08 sec
# epoch 6 (129/272) | step 1490 | avg_nll=20.08 avg_ppl=14.95 speed=9542.14 words/sec time_elapsed=33.33 sec
# epoch 6 (139/272) | step 1500 | avg_nll=18.50 avg_ppl=13.25 speed=9808.05 words/sec time_elapsed=33.56 sec
# Begin validation ...
# validation: step 1500 | dev_ppl=14.77696704864502
# epoch 6 step 1500: save currently the best model to 'model.pt'
# epoch 6 (149/272) | step 1510 | avg_nll=20.06 avg_ppl=15.41 speed=6074.55 words/sec time_elapsed=33.95 sec
# epoch 6 (159/272) | step 1520 | avg_nll=18.64 avg_ppl=13.66 speed=8915.83 words/sec time_elapsed=34.21 sec
# epoch 6 (169/272) | step 1530 | avg_nll=19.13 avg_ppl=14.22 speed=9148.16 words/sec time_elapsed=34.46 sec
# epoch 6 (179/272) | step 1540 | avg_nll=19.14 avg_ppl=14.33 speed=9913.03 words/sec time_elapsed=34.69 sec
# epoch 6 (189/272) | step 1550 | avg_nll=19.42 avg_ppl=14.16 speed=10044.54 words/sec time_elapsed=34.92 sec
# epoch 6 (199/272) | step 1560 | avg_nll=19.77 avg_ppl=15.03 speed=10327.78 words/sec time_elapsed=35.15 sec
# epoch 6 (209/272) | step 1570 | avg_nll=18.40 avg_ppl=12.56 speed=9594.19 words/sec time_elapsed=35.39 sec
# epoch 6 (219/272) | step 1580 | avg_nll=18.68 avg_ppl=13.47 speed=9977.76 words/sec time_elapsed=35.62 sec
# epoch 6 (229/272) | step 1590 | avg_nll=18.46 avg_ppl=12.87 speed=10351.22 words/sec time_elapsed=35.85 sec
# epoch 6 (239/272) | step 1600 | avg_nll=19.53 avg_ppl=14.42 speed=9404.19 words/sec time_elapsed=36.10 sec
# Begin validation ...
# validation: step 1600 | dev_ppl=14.228476524353027
# epoch 6 step 1600: save currently the best model to 'model.pt'
# epoch 6 (249/272) | step 1610 | avg_nll=20.38 avg_ppl=15.53 speed=5616.28 words/sec time_elapsed=36.52 sec
# epoch 6 (259/272) | step 1620 | avg_nll=19.23 avg_ppl=13.89 speed=8997.14 words/sec time_elapsed=36.78 sec
# epoch 6 (269/272) | step 1630 | avg_nll=18.43 avg_ppl=12.97 speed=9964.38 words/sec time_elapsed=37.01 sec
# epoch 7 (7/272) | step 1640 | avg_nll=18.25 avg_ppl=12.89 speed=9565.48 words/sec time_elapsed=37.25 sec
# epoch 7 (17/272) | step 1650 | avg_nll=19.08 avg_ppl=14.45 speed=11282.89 words/sec time_elapsed=37.45 sec
# epoch 7 (27/272) | step 1660 | avg_nll=18.91 avg_ppl=13.81 speed=8769.36 words/sec time_elapsed=37.71 sec
# epoch 7 (37/272) | step 1670 | avg_nll=17.96 avg_ppl=12.34 speed=9313.84 words/sec time_elapsed=37.96 sec
# epoch 7 (47/272) | step 1680 | avg_nll=17.42 avg_ppl=11.59 speed=8387.69 words/sec time_elapsed=38.23 sec
# epoch 7 (57/272) | step 1690 | avg_nll=18.09 avg_ppl=12.08 speed=9455.31 words/sec time_elapsed=38.48 sec
# epoch 7 (67/272) | step 1700 | avg_nll=17.79 avg_ppl=11.58 speed=9854.27 words/sec time_elapsed=38.71 sec
# Begin validation ...
# validation: step 1700 | dev_ppl=13.783263206481934
# epoch 7 step 1700: save currently the best model to 'model.pt'
# epoch 7 (77/272) | step 1710 | avg_nll=18.21 avg_ppl=12.06 speed=5373.26 words/sec time_elapsed=39.15 sec
# epoch 7 (87/272) | step 1720 | avg_nll=18.78 avg_ppl=13.56 speed=8729.85 words/sec time_elapsed=39.41 sec
# epoch 7 (97/272) | step 1730 | avg_nll=17.68 avg_ppl=11.55 speed=9886.81 words/sec time_elapsed=39.65 sec
# epoch 7 (107/272) | step 1740 | avg_nll=17.74 avg_ppl=12.24 speed=9533.02 words/sec time_elapsed=39.89 sec
# epoch 7 (117/272) | step 1750 | avg_nll=18.66 avg_ppl=13.04 speed=9537.19 words/sec time_elapsed=40.13 sec
# epoch 7 (127/272) | step 1760 | avg_nll=17.48 avg_ppl=11.26 speed=9873.16 words/sec time_elapsed=40.36 sec
# epoch 7 (137/272) | step 1770 | avg_nll=18.87 avg_ppl=13.44 speed=9051.14 words/sec time_elapsed=40.62 sec
# epoch 7 (147/272) | step 1780 | avg_nll=17.73 avg_ppl=11.45 speed=9509.14 words/sec time_elapsed=40.86 sec
# epoch 7 (157/272) | step 1790 | avg_nll=19.65 avg_ppl=14.08 speed=9367.61 words/sec time_elapsed=41.12 sec
# epoch 7 (167/272) | step 1800 | avg_nll=18.52 avg_ppl=12.43 speed=9762.37 words/sec time_elapsed=41.36 sec
# Begin validation ...
# validation: step 1800 | dev_ppl=13.356416702270508
# epoch 7 step 1800: save currently the best model to 'model.pt'
# epoch 7 (177/272) | step 1810 | avg_nll=19.11 avg_ppl=13.61 speed=6687.42 words/sec time_elapsed=41.71 sec
# epoch 7 (187/272) | step 1820 | avg_nll=17.82 avg_ppl=11.91 speed=11540.15 words/sec time_elapsed=41.91 sec
# epoch 7 (197/272) | step 1830 | avg_nll=18.46 avg_ppl=13.46 speed=13438.96 words/sec time_elapsed=42.08 sec
# epoch 7 (207/272) | step 1840 | avg_nll=18.34 avg_ppl=12.89 speed=13618.18 words/sec time_elapsed=42.25 sec
# epoch 7 (217/272) | step 1850 | avg_nll=18.40 avg_ppl=12.21 speed=13901.37 words/sec time_elapsed=42.42 sec
# epoch 7 (227/272) | step 1860 | avg_nll=18.58 avg_ppl=12.85 speed=13775.65 words/sec time_elapsed=42.58 sec
# epoch 7 (237/272) | step 1870 | avg_nll=17.72 avg_ppl=11.78 speed=13300.36 words/sec time_elapsed=42.76 sec
# epoch 7 (247/272) | step 1880 | avg_nll=17.92 avg_ppl=11.72 speed=13791.35 words/sec time_elapsed=42.93 sec
# epoch 7 (257/272) | step 1890 | avg_nll=19.14 avg_ppl=13.09 speed=14115.19 words/sec time_elapsed=43.10 sec
# epoch 7 (267/272) | step 1900 | avg_nll=17.76 avg_ppl=11.60 speed=13729.24 words/sec time_elapsed=43.26 sec
# Begin validation ...
# validation: step 1900 | dev_ppl=13.330650329589844
# epoch 7 step 1900: save currently the best model to 'model.pt'
# epoch 8 (5/272) | step 1910 | avg_nll=17.01 avg_ppl=10.79 speed=7662.87 words/sec time_elapsed=43.56 sec
# epoch 8 (15/272) | step 1920 | avg_nll=17.83 avg_ppl=11.50 speed=12440.93 words/sec time_elapsed=43.75 sec
# epoch 8 (25/272) | step 1930 | avg_nll=17.80 avg_ppl=11.88 speed=13337.32 words/sec time_elapsed=43.92 sec
# epoch 8 (35/272) | step 1940 | avg_nll=18.71 avg_ppl=13.21 speed=13315.47 words/sec time_elapsed=44.10 sec
# epoch 8 (45/272) | step 1950 | avg_nll=18.42 avg_ppl=12.74 speed=13706.43 words/sec time_elapsed=44.27 sec
# epoch 8 (55/272) | step 1960 | avg_nll=17.02 avg_ppl=10.90 speed=13394.61 words/sec time_elapsed=44.44 sec
# epoch 8 (65/272) | step 1970 | avg_nll=17.73 avg_ppl=11.58 speed=13666.36 words/sec time_elapsed=44.61 sec
# epoch 8 (75/272) | step 1980 | avg_nll=18.00 avg_ppl=11.85 speed=13462.08 words/sec time_elapsed=44.78 sec
# epoch 8 (85/272) | step 1990 | avg_nll=17.39 avg_ppl=11.41 speed=12989.37 words/sec time_elapsed=44.96 sec
# epoch 8 (95/272) | step 2000 | avg_nll=16.57 avg_ppl=9.96 speed=13531.02 words/sec time_elapsed=45.13 sec
# Begin validation ...
# validation: step 2000 | dev_ppl=13.039349555969238
# epoch 8 step 2000: save currently the best model to 'model.pt'
# epoch 8 (105/272) | step 2010 | avg_nll=18.08 avg_ppl=11.75 speed=7494.76 words/sec time_elapsed=45.44 sec
# epoch 8 (115/272) | step 2020 | avg_nll=18.32 avg_ppl=12.06 speed=13351.39 words/sec time_elapsed=45.62 sec
# epoch 8 (125/272) | step 2030 | avg_nll=17.48 avg_ppl=11.11 speed=12848.03 words/sec time_elapsed=45.80 sec
# epoch 8 (135/272) | step 2040 | avg_nll=17.86 avg_ppl=11.80 speed=12387.81 words/sec time_elapsed=45.98 sec
# epoch 8 (145/272) | step 2050 | avg_nll=17.22 avg_ppl=10.80 speed=13003.02 words/sec time_elapsed=46.16 sec
# epoch 8 (155/272) | step 2060 | avg_nll=17.53 avg_ppl=11.21 speed=13004.50 words/sec time_elapsed=46.34 sec
# epoch 8 (165/272) | step 2070 | avg_nll=16.98 avg_ppl=10.57 speed=12651.72 words/sec time_elapsed=46.52 sec
# epoch 8 (175/272) | step 2080 | avg_nll=17.19 avg_ppl=10.89 speed=13144.44 words/sec time_elapsed=46.70 sec
# epoch 8 (185/272) | step 2090 | avg_nll=18.46 avg_ppl=12.42 speed=12917.67 words/sec time_elapsed=46.88 sec
# epoch 8 (195/272) | step 2100 | avg_nll=17.66 avg_ppl=11.13 speed=13807.37 words/sec time_elapsed=47.05 sec
# Begin validation ...
# validation: step 2100 | dev_ppl=12.323270797729492
# epoch 8 step 2100: save currently the best model to 'model.pt'
# epoch 8 (205/272) | step 2110 | avg_nll=17.31 avg_ppl=10.76 speed=7488.13 words/sec time_elapsed=47.36 sec
# epoch 8 (215/272) | step 2120 | avg_nll=17.26 avg_ppl=10.87 speed=13256.33 words/sec time_elapsed=47.54 sec
# epoch 8 (225/272) | step 2130 | avg_nll=17.72 avg_ppl=11.59 speed=13092.70 words/sec time_elapsed=47.71 sec
# epoch 8 (235/272) | step 2140 | avg_nll=16.99 avg_ppl=10.76 speed=13198.87 words/sec time_elapsed=47.89 sec
# epoch 8 (245/272) | step 2150 | avg_nll=16.84 avg_ppl=10.50 speed=12975.35 words/sec time_elapsed=48.06 sec
# epoch 8 (255/272) | step 2160 | avg_nll=17.19 avg_ppl=10.97 speed=13218.69 words/sec time_elapsed=48.24 sec
# epoch 8 (265/272) | step 2170 | avg_nll=18.17 avg_ppl=11.75 speed=13876.88 words/sec time_elapsed=48.41 sec
# epoch 9 (3/272) | step 2180 | avg_nll=17.65 avg_ppl=11.42 speed=13456.73 words/sec time_elapsed=48.58 sec
# epoch 9 (13/272) | step 2190 | avg_nll=17.37 avg_ppl=11.12 speed=13209.36 words/sec time_elapsed=48.75 sec
# epoch 9 (23/272) | step 2200 | avg_nll=17.05 avg_ppl=10.14 speed=13577.79 words/sec time_elapsed=48.93 sec
# Begin validation ...
# validation: step 2200 | dev_ppl=12.205050468444824
# epoch 9 step 2200: save currently the best model to 'model.pt'
# epoch 9 (33/272) | step 2210 | avg_nll=16.52 avg_ppl=10.16 speed=7526.89 words/sec time_elapsed=49.23 sec
# epoch 9 (43/272) | step 2220 | avg_nll=17.68 avg_ppl=11.52 speed=13613.42 words/sec time_elapsed=49.40 sec
# epoch 9 (53/272) | step 2230 | avg_nll=17.08 avg_ppl=10.65 speed=13230.11 words/sec time_elapsed=49.57 sec
# epoch 9 (63/272) | step 2240 | avg_nll=16.72 avg_ppl=10.26 speed=13247.90 words/sec time_elapsed=49.75 sec
# epoch 9 (73/272) | step 2250 | avg_nll=16.92 avg_ppl=10.03 speed=13684.64 words/sec time_elapsed=49.92 sec
# epoch 9 (83/272) | step 2260 | avg_nll=16.31 avg_ppl=9.77 speed=13270.73 words/sec time_elapsed=50.09 sec
# epoch 9 (93/272) | step 2270 | avg_nll=16.69 avg_ppl=10.15 speed=13063.05 words/sec time_elapsed=50.27 sec
# epoch 9 (103/272) | step 2280 | avg_nll=16.46 avg_ppl=10.02 speed=13594.13 words/sec time_elapsed=50.44 sec
# epoch 9 (113/272) | step 2290 | avg_nll=16.72 avg_ppl=10.16 speed=13473.41 words/sec time_elapsed=50.61 sec
# epoch 9 (123/272) | step 2300 | avg_nll=17.20 avg_ppl=10.28 speed=13931.94 words/sec time_elapsed=50.78 sec
# Begin validation ...
# validation: step 2300 | dev_ppl=11.777956008911133
# epoch 9 step 2300: save currently the best model to 'model.pt'
# epoch 9 (133/272) | step 2310 | avg_nll=16.07 avg_ppl=9.23 speed=7467.19 words/sec time_elapsed=51.09 sec
# epoch 9 (143/272) | step 2320 | avg_nll=17.29 avg_ppl=10.51 speed=12894.52 words/sec time_elapsed=51.27 sec
# epoch 9 (153/272) | step 2330 | avg_nll=17.51 avg_ppl=10.96 speed=13577.68 words/sec time_elapsed=51.44 sec
# epoch 9 (163/272) | step 2340 | avg_nll=17.31 avg_ppl=11.06 speed=13506.61 words/sec time_elapsed=51.61 sec
# epoch 9 (173/272) | step 2350 | avg_nll=17.43 avg_ppl=10.95 speed=13654.86 words/sec time_elapsed=51.78 sec
# epoch 9 (183/272) | step 2360 | avg_nll=16.06 avg_ppl=9.48 speed=13302.18 words/sec time_elapsed=51.95 sec
# epoch 9 (193/272) | step 2370 | avg_nll=16.72 avg_ppl=10.10 speed=13349.92 words/sec time_elapsed=52.13 sec
# epoch 9 (203/272) | step 2380 | avg_nll=17.18 avg_ppl=10.76 speed=13170.98 words/sec time_elapsed=52.30 sec
# epoch 9 (213/272) | step 2390 | avg_nll=16.86 avg_ppl=9.77 speed=13490.56 words/sec time_elapsed=52.48 sec
# epoch 9 (223/272) | step 2400 | avg_nll=16.81 avg_ppl=9.98 speed=13372.85 words/sec time_elapsed=52.65 sec
# Begin validation ...
# validation: step 2400 | dev_ppl=11.54127311706543
# epoch 9 step 2400: save currently the best model to 'model.pt'
# epoch 9 (233/272) | step 2410 | avg_nll=16.18 avg_ppl=9.42 speed=7638.43 words/sec time_elapsed=52.96 sec
# epoch 9 (243/272) | step 2420 | avg_nll=16.17 avg_ppl=9.65 speed=13054.25 words/sec time_elapsed=53.13 sec
# epoch 9 (253/272) | step 2430 | avg_nll=17.05 avg_ppl=10.59 speed=13486.47 words/sec time_elapsed=53.30 sec
# epoch 9 (263/272) | step 2440 | avg_nll=16.78 avg_ppl=10.30 speed=13693.02 words/sec time_elapsed=53.47 sec
# epoch 10 (1/272) | step 2450 | avg_nll=16.32 avg_ppl=9.56 speed=13340.58 words/sec time_elapsed=53.65 sec
# epoch 10 (11/272) | step 2460 | avg_nll=15.72 avg_ppl=9.14 speed=12234.99 words/sec time_elapsed=53.83 sec
# epoch 10 (21/272) | step 2470 | avg_nll=16.04 avg_ppl=9.22 speed=11445.01 words/sec time_elapsed=54.03 sec
# epoch 10 (31/272) | step 2480 | avg_nll=15.71 avg_ppl=8.89 speed=12533.19 words/sec time_elapsed=54.22 sec
# epoch 10 (41/272) | step 2490 | avg_nll=16.84 avg_ppl=9.87 speed=13597.37 words/sec time_elapsed=54.39 sec
# epoch 10 (51/272) | step 2500 | avg_nll=16.16 avg_ppl=9.30 speed=13328.95 words/sec time_elapsed=54.56 sec
# Begin validation ...
# validation: step 2500 | dev_ppl=11.677701950073242
# epoch 10 (61/272) | step 2510 | avg_nll=15.78 avg_ppl=8.98 speed=8020.33 words/sec time_elapsed=54.85 sec
# epoch 10 (71/272) | step 2520 | avg_nll=16.38 avg_ppl=9.83 speed=13192.37 words/sec time_elapsed=55.02 sec
# epoch 10 (81/272) | step 2530 | avg_nll=15.51 avg_ppl=8.60 speed=13424.13 words/sec time_elapsed=55.20 sec
# epoch 10 (91/272) | step 2540 | avg_nll=15.49 avg_ppl=8.53 speed=13336.35 words/sec time_elapsed=55.37 sec
# epoch 10 (101/272) | step 2550 | avg_nll=15.16 avg_ppl=8.64 speed=13041.94 words/sec time_elapsed=55.54 sec
# epoch 10 (111/272) | step 2560 | avg_nll=16.89 avg_ppl=10.20 speed=13563.35 words/sec time_elapsed=55.71 sec
# epoch 10 (121/272) | step 2570 | avg_nll=17.05 avg_ppl=9.86 speed=13934.22 words/sec time_elapsed=55.88 sec
# epoch 10 (131/272) | step 2580 | avg_nll=15.86 avg_ppl=9.06 speed=13393.94 words/sec time_elapsed=56.06 sec
# epoch 10 (141/272) | step 2590 | avg_nll=16.86 avg_ppl=10.06 speed=13342.69 words/sec time_elapsed=56.23 sec
# epoch 10 (151/272) | step 2600 | avg_nll=16.54 avg_ppl=9.76 speed=13543.98 words/sec time_elapsed=56.40 sec
# Begin validation ...
# validation: step 2600 | dev_ppl=11.43674373626709
# epoch 10 step 2600: save currently the best model to 'model.pt'
# epoch 10 (161/272) | step 2610 | avg_nll=16.34 avg_ppl=9.72 speed=7457.31 words/sec time_elapsed=56.71 sec
# epoch 10 (171/272) | step 2620 | avg_nll=17.26 avg_ppl=10.28 speed=13750.16 words/sec time_elapsed=56.88 sec
# epoch 10 (181/272) | step 2630 | avg_nll=15.01 avg_ppl=8.56 speed=12647.85 words/sec time_elapsed=57.06 sec
# epoch 10 (191/272) | step 2640 | avg_nll=17.81 avg_ppl=11.48 speed=13602.81 words/sec time_elapsed=57.23 sec
# epoch 10 (201/272) | step 2650 | avg_nll=16.16 avg_ppl=9.17 speed=13630.08 words/sec time_elapsed=57.40 sec
# epoch 10 (211/272) | step 2660 | avg_nll=15.84 avg_ppl=8.98 speed=13665.43 words/sec time_elapsed=57.57 sec
# epoch 10 (221/272) | step 2670 | avg_nll=16.01 avg_ppl=9.22 speed=13445.94 words/sec time_elapsed=57.74 sec
# epoch 10 (231/272) | step 2680 | avg_nll=16.17 avg_ppl=9.37 speed=13491.14 words/sec time_elapsed=57.92 sec
# epoch 10 (241/272) | step 2690 | avg_nll=16.02 avg_ppl=8.98 speed=13631.53 words/sec time_elapsed=58.09 sec
# epoch 10 (251/272) | step 2700 | avg_nll=16.69 avg_ppl=9.85 speed=13571.50 words/sec time_elapsed=58.26 sec
# Begin validation ...
# validation: step 2700 | dev_ppl=10.806151390075684
# epoch 10 step 2700: save currently the best model to 'model.pt'
# epoch 10 (261/272) | step 2710 | avg_nll=16.65 avg_ppl=9.63 speed=7910.73 words/sec time_elapsed=58.56 sec
# epoch 10 (271/272) | step 2720 | avg_nll=15.78 avg_ppl=8.78 speed=13358.79 words/sec time_elapsed=58.73 sec
# epoch 11 (9/272) | step 2730 | avg_nll=15.45 avg_ppl=8.57 speed=12682.20 words/sec time_elapsed=58.91 sec
# epoch 11 (19/272) | step 2740 | avg_nll=15.22 avg_ppl=8.22 speed=12723.50 words/sec time_elapsed=59.09 sec
# epoch 11 (29/272) | step 2750 | avg_nll=15.96 avg_ppl=8.94 speed=13102.23 words/sec time_elapsed=59.27 sec
# epoch 11 (39/272) | step 2760 | avg_nll=16.30 avg_ppl=9.27 speed=13592.77 words/sec time_elapsed=59.44 sec
# epoch 11 (49/272) | step 2770 | avg_nll=15.93 avg_ppl=8.77 speed=13579.81 words/sec time_elapsed=59.62 sec
# epoch 11 (59/272) | step 2780 | avg_nll=15.81 avg_ppl=8.72 speed=13135.18 words/sec time_elapsed=59.79 sec
# epoch 11 (69/272) | step 2790 | avg_nll=14.80 avg_ppl=7.88 speed=13472.34 words/sec time_elapsed=59.96 sec
# epoch 11 (79/272) | step 2800 | avg_nll=15.20 avg_ppl=8.41 speed=12924.18 words/sec time_elapsed=60.14 sec
# Begin validation ...
# validation: step 2800 | dev_ppl=10.791362762451172
# epoch 11 step 2800: save currently the best model to 'model.pt'
# epoch 11 (89/272) | step 2810 | avg_nll=15.13 avg_ppl=8.07 speed=7429.17 words/sec time_elapsed=60.45 sec
# epoch 11 (99/272) | step 2820 | avg_nll=15.20 avg_ppl=8.31 speed=13497.45 words/sec time_elapsed=60.62 sec
# epoch 11 (109/272) | step 2830 | avg_nll=15.37 avg_ppl=8.44 speed=13234.48 words/sec time_elapsed=60.80 sec
# epoch 11 (119/272) | step 2840 | avg_nll=15.37 avg_ppl=8.41 speed=13246.56 words/sec time_elapsed=60.97 sec
# epoch 11 (129/272) | step 2850 | avg_nll=15.42 avg_ppl=8.40 speed=13056.05 words/sec time_elapsed=61.15 sec
# epoch 11 (139/272) | step 2860 | avg_nll=15.20 avg_ppl=8.06 speed=12892.05 words/sec time_elapsed=61.33 sec
# epoch 11 (149/272) | step 2870 | avg_nll=14.94 avg_ppl=7.87 speed=12937.27 words/sec time_elapsed=61.51 sec
# epoch 11 (159/272) | step 2880 | avg_nll=15.82 avg_ppl=8.81 speed=13293.47 words/sec time_elapsed=61.69 sec
# epoch 11 (169/272) | step 2890 | avg_nll=16.97 avg_ppl=9.98 speed=13310.18 words/sec time_elapsed=61.86 sec
# epoch 11 (179/272) | step 2900 | avg_nll=15.09 avg_ppl=8.27 speed=12702.52 words/sec time_elapsed=62.04 sec
# Begin validation ...
# validation: step 2900 | dev_ppl=10.482576370239258
# epoch 11 step 2900: save currently the best model to 'model.pt'
# epoch 11 (189/272) | step 2910 | avg_nll=15.65 avg_ppl=8.95 speed=7176.06 words/sec time_elapsed=62.36 sec
# epoch 11 (199/272) | step 2920 | avg_nll=14.71 avg_ppl=8.03 speed=12166.79 words/sec time_elapsed=62.55 sec
# epoch 11 (209/272) | step 2930 | avg_nll=16.44 avg_ppl=9.01 speed=12878.15 words/sec time_elapsed=62.73 sec
# epoch 11 (219/272) | step 2940 | avg_nll=16.65 avg_ppl=9.65 speed=13386.03 words/sec time_elapsed=62.91 sec
# epoch 11 (229/272) | step 2950 | avg_nll=17.00 avg_ppl=9.96 speed=13823.31 words/sec time_elapsed=63.08 sec
# epoch 11 (239/272) | step 2960 | avg_nll=15.09 avg_ppl=8.27 speed=12750.80 words/sec time_elapsed=63.26 sec
# epoch 11 (249/272) | step 2970 | avg_nll=16.13 avg_ppl=9.22 speed=13169.13 words/sec time_elapsed=63.44 sec
# epoch 11 (259/272) | step 2980 | avg_nll=14.02 avg_ppl=7.32 speed=12874.46 words/sec time_elapsed=63.61 sec
# epoch 11 (269/272) | step 2990 | avg_nll=15.95 avg_ppl=8.91 speed=13845.45 words/sec time_elapsed=63.78 sec
# epoch 12 (7/272) | step 3000 | avg_nll=15.67 avg_ppl=8.71 speed=12904.73 words/sec time_elapsed=63.96 sec
# Begin validation ...
# validation: step 3000 | dev_ppl=10.661640167236328
# epoch 12 (17/272) | step 3010 | avg_nll=14.48 avg_ppl=7.70 speed=8134.88 words/sec time_elapsed=64.24 sec
# epoch 12 (27/272) | step 3020 | avg_nll=14.65 avg_ppl=7.87 speed=13271.40 words/sec time_elapsed=64.41 sec
# epoch 12 (37/272) | step 3030 | avg_nll=14.62 avg_ppl=7.50 speed=13354.62 words/sec time_elapsed=64.58 sec
# epoch 12 (47/272) | step 3040 | avg_nll=15.98 avg_ppl=9.10 speed=13696.44 words/sec time_elapsed=64.75 sec
# epoch 12 (57/272) | step 3050 | avg_nll=14.80 avg_ppl=7.85 speed=12930.23 words/sec time_elapsed=64.93 sec
# epoch 12 (67/272) | step 3060 | avg_nll=13.53 avg_ppl=6.70 speed=13563.58 words/sec time_elapsed=65.10 sec
# epoch 12 (77/272) | step 3070 | avg_nll=15.43 avg_ppl=8.11 speed=13466.01 words/sec time_elapsed=65.27 sec
# epoch 12 (87/272) | step 3080 | avg_nll=14.66 avg_ppl=7.53 speed=13309.12 words/sec time_elapsed=65.45 sec
# epoch 12 (97/272) | step 3090 | avg_nll=14.91 avg_ppl=7.76 speed=13572.91 words/sec time_elapsed=65.62 sec
# epoch 12 (107/272) | step 3100 | avg_nll=15.99 avg_ppl=8.76 speed=14020.27 words/sec time_elapsed=65.79 sec
# Begin validation ...
# validation: step 3100 | dev_ppl=10.156901359558105
# epoch 12 step 3100: save currently the best model to 'model.pt'
# epoch 12 (117/272) | step 3110 | avg_nll=15.18 avg_ppl=7.91 speed=7791.58 words/sec time_elapsed=66.09 sec
# epoch 12 (127/272) | step 3120 | avg_nll=14.82 avg_ppl=7.82 speed=13309.28 words/sec time_elapsed=66.26 sec
# epoch 12 (137/272) | step 3130 | avg_nll=15.62 avg_ppl=8.75 speed=13617.89 words/sec time_elapsed=66.43 sec
# epoch 12 (147/272) | step 3140 | avg_nll=14.55 avg_ppl=7.42 speed=13510.78 words/sec time_elapsed=66.60 sec
# epoch 12 (157/272) | step 3150 | avg_nll=14.98 avg_ppl=7.89 speed=13754.11 words/sec time_elapsed=66.77 sec
# epoch 12 (167/272) | step 3160 | avg_nll=15.73 avg_ppl=8.37 speed=13311.45 words/sec time_elapsed=66.95 sec
# epoch 12 (177/272) | step 3170 | avg_nll=14.15 avg_ppl=7.18 speed=13613.02 words/sec time_elapsed=67.12 sec
# epoch 12 (187/272) | step 3180 | avg_nll=14.51 avg_ppl=7.73 speed=13423.31 words/sec time_elapsed=67.29 sec
# epoch 12 (197/272) | step 3190 | avg_nll=15.16 avg_ppl=8.25 speed=12915.96 words/sec time_elapsed=67.47 sec
# epoch 12 (207/272) | step 3200 | avg_nll=13.74 avg_ppl=7.00 speed=12881.59 words/sec time_elapsed=67.64 sec
# Begin validation ...
# validation: step 3200 | dev_ppl=10.275801658630371
# epoch 12 (217/272) | step 3210 | avg_nll=15.29 avg_ppl=8.18 speed=8289.72 words/sec time_elapsed=67.92 sec
# epoch 12 (227/272) | step 3220 | avg_nll=15.48 avg_ppl=8.14 speed=13970.05 words/sec time_elapsed=68.09 sec
# epoch 12 (237/272) | step 3230 | avg_nll=15.03 avg_ppl=7.90 speed=13396.76 words/sec time_elapsed=68.27 sec
# epoch 12 (247/272) | step 3240 | avg_nll=15.45 avg_ppl=8.28 speed=13599.16 words/sec time_elapsed=68.44 sec
# epoch 12 (257/272) | step 3250 | avg_nll=14.94 avg_ppl=7.91 speed=13527.90 words/sec time_elapsed=68.61 sec
# epoch 12 (267/272) | step 3260 | avg_nll=15.02 avg_ppl=7.72 speed=13853.77 words/sec time_elapsed=68.78 sec
# epoch 13 (5/272) | step 3270 | avg_nll=14.34 avg_ppl=7.45 speed=13436.74 words/sec time_elapsed=68.95 sec
# epoch 13 (15/272) | step 3280 | avg_nll=13.70 avg_ppl=6.64 speed=13531.13 words/sec time_elapsed=69.12 sec
# epoch 13 (25/272) | step 3290 | avg_nll=14.24 avg_ppl=7.08 speed=13486.19 words/sec time_elapsed=69.29 sec
# epoch 13 (35/272) | step 3300 | avg_nll=14.36 avg_ppl=7.12 speed=13741.25 words/sec time_elapsed=69.46 sec
# Begin validation ...
# validation: step 3300 | dev_ppl=10.252998352050781
# epoch 13 (45/272) | step 3310 | avg_nll=13.73 avg_ppl=6.85 speed=7841.92 words/sec time_elapsed=69.75 sec
# epoch 13 (55/272) | step 3320 | avg_nll=13.71 avg_ppl=6.77 speed=11351.84 words/sec time_elapsed=69.96 sec
# epoch 13 (65/272) | step 3330 | avg_nll=13.82 avg_ppl=6.91 speed=11593.36 words/sec time_elapsed=70.15 sec
# epoch 13 (75/272) | step 3340 | avg_nll=14.57 avg_ppl=7.48 speed=12504.91 words/sec time_elapsed=70.34 sec
# epoch 13 (85/272) | step 3350 | avg_nll=15.45 avg_ppl=8.18 speed=13247.02 words/sec time_elapsed=70.52 sec
# epoch 13 (95/272) | step 3360 | avg_nll=13.86 avg_ppl=7.04 speed=13311.94 words/sec time_elapsed=70.69 sec
# epoch 13 (105/272) | step 3370 | avg_nll=15.56 avg_ppl=8.53 speed=13709.73 words/sec time_elapsed=70.86 sec
# epoch 13 (115/272) | step 3380 | avg_nll=14.36 avg_ppl=7.14 speed=13484.82 words/sec time_elapsed=71.03 sec
# epoch 13 (125/272) | step 3390 | avg_nll=15.22 avg_ppl=8.10 speed=13664.94 words/sec time_elapsed=71.20 sec
# epoch 13 (135/272) | step 3400 | avg_nll=15.34 avg_ppl=8.30 speed=13135.58 words/sec time_elapsed=71.38 sec
# Begin validation ...
# validation: step 3400 | dev_ppl=9.846102714538574
# epoch 13 step 3400: save currently the best model to 'model.pt'
# epoch 13 (145/272) | step 3410 | avg_nll=14.60 avg_ppl=7.43 speed=7460.65 words/sec time_elapsed=71.69 sec
# epoch 13 (155/272) | step 3420 | avg_nll=15.88 avg_ppl=8.30 speed=13594.85 words/sec time_elapsed=71.87 sec
# epoch 13 (165/272) | step 3430 | avg_nll=14.68 avg_ppl=7.25 speed=13482.98 words/sec time_elapsed=72.04 sec
# epoch 13 (175/272) | step 3440 | avg_nll=15.10 avg_ppl=8.03 speed=13116.71 words/sec time_elapsed=72.22 sec
# epoch 13 (185/272) | step 3450 | avg_nll=13.63 avg_ppl=6.84 speed=12954.16 words/sec time_elapsed=72.39 sec
# epoch 13 (195/272) | step 3460 | avg_nll=15.23 avg_ppl=7.93 speed=13788.17 words/sec time_elapsed=72.57 sec
# epoch 13 (205/272) | step 3470 | avg_nll=14.32 avg_ppl=7.32 speed=13201.54 words/sec time_elapsed=72.74 sec
# epoch 13 (215/272) | step 3480 | avg_nll=13.91 avg_ppl=6.85 speed=13549.00 words/sec time_elapsed=72.91 sec
# epoch 13 (225/272) | step 3490 | avg_nll=13.99 avg_ppl=6.98 speed=13435.70 words/sec time_elapsed=73.08 sec
# epoch 13 (235/272) | step 3500 | avg_nll=14.25 avg_ppl=7.17 speed=13646.32 words/sec time_elapsed=73.25 sec
# Begin validation ...
# validation: step 3500 | dev_ppl=9.774981498718262
# epoch 13 step 3500: save currently the best model to 'model.pt'
# epoch 13 (245/272) | step 3510 | avg_nll=13.87 avg_ppl=6.80 speed=6611.23 words/sec time_elapsed=73.60 sec
# epoch 13 (255/272) | step 3520 | avg_nll=14.19 avg_ppl=7.02 speed=9064.36 words/sec time_elapsed=73.86 sec
# epoch 13 (265/272) | step 3530 | avg_nll=14.31 avg_ppl=7.32 speed=10142.59 words/sec time_elapsed=74.09 sec
# epoch 14 (3/272) | step 3540 | avg_nll=13.27 avg_ppl=6.79 speed=9572.08 words/sec time_elapsed=74.32 sec
# epoch 14 (13/272) | step 3550 | avg_nll=14.56 avg_ppl=7.15 speed=9904.78 words/sec time_elapsed=74.56 sec
# epoch 14 (23/272) | step 3560 | avg_nll=12.94 avg_ppl=6.01 speed=10039.30 words/sec time_elapsed=74.79 sec
# epoch 14 (33/272) | step 3570 | avg_nll=14.56 avg_ppl=7.28 speed=11382.57 words/sec time_elapsed=74.99 sec
# epoch 14 (43/272) | step 3580 | avg_nll=13.69 avg_ppl=6.66 speed=11724.69 words/sec time_elapsed=75.19 sec
# epoch 14 (53/272) | step 3590 | avg_nll=13.28 avg_ppl=6.46 speed=8963.36 words/sec time_elapsed=75.44 sec
# epoch 14 (63/272) | step 3600 | avg_nll=13.79 avg_ppl=6.76 speed=9334.57 words/sec time_elapsed=75.69 sec
# Begin validation ...
# validation: step 3600 | dev_ppl=9.574410438537598
# epoch 14 step 3600: save currently the best model to 'model.pt'
# epoch 14 (73/272) | step 3610 | avg_nll=14.01 avg_ppl=7.01 speed=6475.96 words/sec time_elapsed=76.05 sec
# epoch 14 (83/272) | step 3620 | avg_nll=14.11 avg_ppl=7.15 speed=12227.19 words/sec time_elapsed=76.23 sec
# epoch 14 (93/272) | step 3630 | avg_nll=14.13 avg_ppl=6.88 speed=9652.92 words/sec time_elapsed=76.48 sec
# epoch 14 (103/272) | step 3640 | avg_nll=14.73 avg_ppl=7.49 speed=9203.26 words/sec time_elapsed=76.73 sec
# epoch 14 (113/272) | step 3650 | avg_nll=14.66 avg_ppl=7.69 speed=9801.84 words/sec time_elapsed=76.97 sec
# epoch 14 (123/272) | step 3660 | avg_nll=14.52 avg_ppl=7.53 speed=11381.58 words/sec time_elapsed=77.17 sec
# epoch 14 (133/272) | step 3670 | avg_nll=13.16 avg_ppl=6.38 speed=12167.93 words/sec time_elapsed=77.36 sec
# epoch 14 (143/272) | step 3680 | avg_nll=13.56 avg_ppl=6.67 speed=12760.06 words/sec time_elapsed=77.53 sec
# epoch 14 (153/272) | step 3690 | avg_nll=13.64 avg_ppl=6.69 speed=12306.81 words/sec time_elapsed=77.72 sec
# epoch 14 (163/272) | step 3700 | avg_nll=13.63 avg_ppl=6.61 speed=12569.56 words/sec time_elapsed=77.90 sec
# Begin validation ...
# validation: step 3700 | dev_ppl=9.784725189208984
# epoch 14 (173/272) | step 3710 | avg_nll=13.73 avg_ppl=6.74 speed=8094.24 words/sec time_elapsed=78.19 sec
# epoch 14 (183/272) | step 3720 | avg_nll=14.45 avg_ppl=7.23 speed=12311.33 words/sec time_elapsed=78.38 sec
# epoch 14 (193/272) | step 3730 | avg_nll=14.28 avg_ppl=6.88 speed=9989.21 words/sec time_elapsed=78.62 sec
# epoch 14 (203/272) | step 3740 | avg_nll=13.67 avg_ppl=6.32 speed=13112.25 words/sec time_elapsed=78.80 sec
# epoch 14 (213/272) | step 3750 | avg_nll=14.33 avg_ppl=7.25 speed=10785.54 words/sec time_elapsed=79.01 sec
# epoch 14 (223/272) | step 3760 | avg_nll=14.48 avg_ppl=7.26 speed=12957.84 words/sec time_elapsed=79.19 sec
# epoch 14 (233/272) | step 3770 | avg_nll=13.26 avg_ppl=6.11 speed=11635.18 words/sec time_elapsed=79.39 sec
# epoch 14 (243/272) | step 3780 | avg_nll=13.28 avg_ppl=6.21 speed=9550.13 words/sec time_elapsed=79.64 sec
# epoch 14 (253/272) | step 3790 | avg_nll=14.46 avg_ppl=7.06 speed=11577.78 words/sec time_elapsed=79.84 sec
# epoch 14 (263/272) | step 3800 | avg_nll=12.83 avg_ppl=6.04 speed=9876.32 words/sec time_elapsed=80.07 sec
# Begin validation ...
# validation: step 3800 | dev_ppl=9.082392692565918
# epoch 14 step 3800: save currently the best model to 'model.pt'
# epoch 15 (1/272) | step 3810 | avg_nll=13.20 avg_ppl=6.42 speed=5897.47 words/sec time_elapsed=80.46 sec
# epoch 15 (11/272) | step 3820 | avg_nll=12.72 avg_ppl=5.87 speed=13205.60 words/sec time_elapsed=80.63 sec
# epoch 15 (21/272) | step 3830 | avg_nll=13.52 avg_ppl=6.42 speed=12248.33 words/sec time_elapsed=80.82 sec
# epoch 15 (31/272) | step 3840 | avg_nll=14.28 avg_ppl=6.93 speed=9917.68 words/sec time_elapsed=81.06 sec
# epoch 15 (41/272) | step 3850 | avg_nll=13.29 avg_ppl=6.13 speed=9180.20 words/sec time_elapsed=81.32 sec
# epoch 15 (51/272) | step 3860 | avg_nll=12.39 avg_ppl=5.70 speed=10393.45 words/sec time_elapsed=81.53 sec
# epoch 15 (61/272) | step 3870 | avg_nll=12.44 avg_ppl=5.75 speed=9296.65 words/sec time_elapsed=81.78 sec
# epoch 15 (71/272) | step 3880 | avg_nll=13.42 avg_ppl=6.21 speed=10232.42 words/sec time_elapsed=82.01 sec
# epoch 15 (81/272) | step 3890 | avg_nll=13.15 avg_ppl=6.14 speed=9073.79 words/sec time_elapsed=82.26 sec
# epoch 15 (91/272) | step 3900 | avg_nll=13.36 avg_ppl=6.56 speed=9313.38 words/sec time_elapsed=82.51 sec
# Begin validation ...
# validation: step 3900 | dev_ppl=9.393875122070312
# epoch 15 (101/272) | step 3910 | avg_nll=12.50 avg_ppl=5.76 speed=7778.48 words/sec time_elapsed=82.80 sec
# epoch 15 (111/272) | step 3920 | avg_nll=13.28 avg_ppl=6.36 speed=12735.75 words/sec time_elapsed=82.98 sec
# epoch 15 (121/272) | step 3930 | avg_nll=13.42 avg_ppl=6.26 speed=10786.93 words/sec time_elapsed=83.20 sec
# epoch 15 (131/272) | step 3940 | avg_nll=13.35 avg_ppl=6.31 speed=9687.64 words/sec time_elapsed=83.44 sec
# epoch 15 (141/272) | step 3950 | avg_nll=13.91 avg_ppl=6.58 speed=9191.44 words/sec time_elapsed=83.70 sec
# epoch 15 (151/272) | step 3960 | avg_nll=11.88 avg_ppl=5.24 speed=9898.73 words/sec time_elapsed=83.93 sec
# epoch 15 (161/272) | step 3970 | avg_nll=14.31 avg_ppl=7.06 speed=9877.40 words/sec time_elapsed=84.17 sec
# epoch 15 (171/272) | step 3980 | avg_nll=13.15 avg_ppl=6.33 speed=9015.42 words/sec time_elapsed=84.42 sec
# epoch 15 (181/272) | step 3990 | avg_nll=13.67 avg_ppl=6.51 speed=9553.02 words/sec time_elapsed=84.66 sec
# epoch 15 (191/272) | step 4000 | avg_nll=13.66 avg_ppl=6.76 speed=10850.80 words/sec time_elapsed=84.87 sec
# Begin validation ...
# validation: step 4000 | dev_ppl=8.987936019897461
# epoch 15 step 4000: save currently the best model to 'model.pt'
# epoch 15 (201/272) | step 4010 | avg_nll=13.74 avg_ppl=6.42 speed=5409.27 words/sec time_elapsed=85.31 sec
# epoch 15 (211/272) | step 4020 | avg_nll=12.84 avg_ppl=5.98 speed=9678.06 words/sec time_elapsed=85.55 sec
# epoch 15 (221/272) | step 4030 | avg_nll=13.20 avg_ppl=6.22 speed=9003.76 words/sec time_elapsed=85.81 sec
# epoch 15 (231/272) | step 4040 | avg_nll=14.37 avg_ppl=7.12 speed=10761.02 words/sec time_elapsed=86.02 sec
# epoch 15 (241/272) | step 4050 | avg_nll=13.97 avg_ppl=6.90 speed=12361.65 words/sec time_elapsed=86.21 sec
# epoch 15 (251/272) | step 4060 | avg_nll=13.92 avg_ppl=6.70 speed=9091.78 words/sec time_elapsed=86.47 sec
# epoch 15 (261/272) | step 4070 | avg_nll=13.05 avg_ppl=6.17 speed=9756.73 words/sec time_elapsed=86.70 sec
# epoch 15 (271/272) | step 4080 | avg_nll=13.27 avg_ppl=6.31 speed=8889.47 words/sec time_elapsed=86.96 sec
# Reached maximum number of epochs

# %% [markdown]
# ## Evaluate the model
#
# We have trained a seq2seq model for the NMT task. Now let's evaluate the model on the test set by generating translations with beam search and comparing them to the gold translations using the BLEU score.

# %%
from tqdm import tqdm
from nltk.translate.bleu_score import corpus_bleu

def beam_search(model: EncoderDecoderModel,
                encoder_input_ids: torch.LongTensor,
                beam_width: int = 5,
                max_len: int = 32) -> Tuple[torch.LongTensor, float]:
    """Run beam search on the encoder-decoder model for a single source sequence.
    
    Args:
        model: The encoder-decoder model.
        encoder_input_ids: The input sequence. Tensor of shape [encoder_sequence_length].
        beam_width: Number of generations to expand at each time step.
        max_len: Stop generation when reaching this length for the generated sequence.
    
    Returns:
        A tuple (generation, score) where generation is the generated target sequence and
            a tensor of shape [target_sequence_length] and score is the corresponding
            log-probability of this generation.
    """
    model.eval()
    
    encoder_input_ids = encoder_input_ids.unsqueeze(0) # Add the batch dimension 
    encoder_padding_mask = torch.zeros_like(encoder_input_ids, dtype=torch.bool) # No padding
    encoder_outputs = model.forward_encoder(encoder_input_ids, encoder_padding_mask)
    
    generations = [torch.tensor([target_tokenizer.bos_token_id], device=encoder_input_ids.device)]
    scores = [0.0]
    
    best_generation = None
    best_score = float('-inf')
    
    for _ in range(max_len):
        new_generations = []
        new_scores = []
        for score, generation in zip(scores, generations):
            generation = generation.unsqueeze(0) # Add the batch dimension
            padding_mask = torch.zeros_like(generation, dtype=torch.bool) # No padding
            decoder_output = model.forward_decoder(generation, padding_mask, encoder_outputs, encoder_padding_mask)
            last_log_probs = decoder_output[0, -1, :].log_softmax(dim=-1)
            top_log_probs, top_indices = last_log_probs.topk(beam_width, dim=-1)
            
            new_generations.append(torch.cat([generation.expand(beam_width, -1), top_indices[:,None]], dim=1))
            new_scores.append(score + top_log_probs)
        
        new_generations = torch.cat(new_generations, dim=0)
        new_scores = torch.cat(new_scores, dim=0)
        
        ends_with_eos = target_tokenizer.eos_token_id == new_generations[:,-1]
        
        if ends_with_eos.any():
            new_completed_generations = new_generations[ends_with_eos]
            new_completed_scores = new_scores[ends_with_eos]
            
            if new_completed_scores.max() > best_score:
                best_score = new_completed_scores.max()
                best_generation = new_completed_generations[new_completed_scores.argmax()]

        if best_score >= new_scores.max():
            break
        
        scores, indices = torch.topk(new_scores, beam_width, dim=-1)
        generations = new_generations[indices]
    
    if best_generation is None:
        best_generation = generations[0]
        best_score = scores[0]
    
    return best_generation, best_score.cpu().item()


def run_generation(model, test_dataset, beam_size=5, max_decoding_time_step=32):
    """Run beam search decoding on the test set, compute BLEU and return reference and candidate target sentences.
    """
    
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    print('Use device: %s' % device)
    
    input_sentences = []
    reference_sentences = []
    candidate_sentences = []
    
    with torch.no_grad():
        for example in tqdm(test_dataset):
            encoder_input_ids = torch.tensor(example["encoder_input_ids"], device=device)
            
            generation, _ = beam_search(model, encoder_input_ids, beam_size, max_decoding_time_step)
            
            # Decode given source sequence and generated target sequence and avoid special tokens
            
            input_text = "".join(source_tokenizer.decode(token).replace("▁", " ") for token in example["encoder_input_ids"][1:-1])
            reference_text = "".join(target_tokenizer.decode(token).replace("▁", " ") for token in example["decoder_input_ids"][1:-1])
            candidate_text = "".join(target_tokenizer.decode(token).replace("▁", " ") for token in generation[1:-1].cpu())
            
            reference_sentences.append(reference_text)
            candidate_sentences.append(candidate_text)
            input_sentences.append(input_text)
             

    bleu_score = corpus_bleu([[ref] for ref in reference_sentences],
                             [candidate for candidate in candidate_sentences])

    return bleu_score, input_sentences, reference_sentences, candidate_sentences

# %%
# Restore the best validation checkpoint
model.load_state_dict(torch.load("model.pt"))

bleu_score, inputs, references, candidates = run_generation(model, tokenized_datasets["test"])
print('\n\nCorpus BLEU: {}'.format(bleu_score * 100))
# Out:
# Use device: cuda:0
# 100%|██████████| 486/486 [00:49<00:00,  9.75it/s]
# Corpus BLEU: 46.63080802544404

# %% [markdown]
# Let's look at some examples. What do you think of the quality of the translations?

# %%
# Feel free to change the range to look at more samples!
for k in range(10, 20):
  print(f"===== Sample {k} =====")
  print(f"Input: {inputs[k]}")
  print(f"Gold: {references[k]}")
  print(f"Pred: {candidates[k]}")
# Out:
# ===== Sample 10 =====
# Input:  vous me mettez mal a l aise .
# Gold:  you re embarrassing me .
# Pred:  you re out of good .
# ===== Sample 11 =====
# Input:  c est toi le professeur .
# Gold:  you re the teacher .
# Pred:  you re the teacher .
# ===== Sample 12 =====
# Input:  elle sourit avec bonheur .
# Gold:  she smiled happily .
# Pred:  she people help help .
# ===== Sample 13 =====
# Input:  je ne suis pas devin .
# Gold:  i m not a psychic .
# Pred:  i m not all all .
# ===== Sample 14 =====
# Input:  vous allez perdre .
# Gold:  you re going to lose .
# Pred:  you re going we .
# ===== Sample 15 =====
# Input:  vous me touchez .
# Gold:  you re touching me .
# Pred:  you re really really is .
# ===== Sample 16 =====
# Input:  je pars aujourd hui .
# Gold:  i m leaving today .
# Pred:  i m need .
# ===== Sample 17 =====
# Input:  je ne suis pas une sainte .
# Gold:  i m no saint .
# Pred:  i m not a saint .
# ===== Sample 18 =====
# Input:  je suis puissant .
# Gold:  i m powerful .
# Pred:  i m all .
# ===== Sample 19 =====
# Input:  vous n etes qu un lache .
# Gold:  you re nothing but a coward .
# Pred:  you are bothered sure .

# %% [markdown]
# # Questions
#
# Please answer written questions from the assignment in this section. You can alter the provided code to obtain the answers, but be careful not to break anything!
#
# **(b) (4 points)**
#
# - (i)
#     What vocabulary size are we using for the source and target language?
#
# - (ii)
#     Approximately how many source and target tokens are on average contained in a training batch? What proportion of these tokens are `<pad>` tokens on average?
#
# - (iii)
# What is the specific purpose of saving the model parameters in a file `model.pt` throughout training in the code we provide?
#
# **(c) (2 points)**
# Manually look at some results and compare them with the gold answers. What do you think of the quality of the translations? Are these grammatical English sentences? Can you identify any common mistakes?
#
# **(d) (4 points)**
# Consider the provided beam search method. This implementation is not efficient and performs a lot of repeated computation. Identify the issue and propose how you can fix it.
# In particular, describe how would you have to change the arguments and return values of your EncoderDecoderModel and its sub-modules?
